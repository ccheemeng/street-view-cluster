# %% [markdown]
# This notebook describes a pipeline to download panoramas and their corresponding depth maps from Google Street View.
# It takes an input ```.json``` describing a list of EPSG:4326 latitude/longitude pairs (as a list of length 2), and attempts to save the panorama as a ```.jpg``` and a 3D cartesian point cloud derived from the depth map as a ```.json``` in the target directory.
# A ```.csv``` indicating the panorama IDs (which correspond to the filenames) with the true latitude, longitude, and elevation is also saved.

# %%
target_dir = "data"
input_latlons_fp = "place-pulse-singapore-latlons.json"
pano_dir = "panos"
point_cloud_dir = "point-clouds"
log_filename = "street-view-id.csv"

# %%
import aiocsv
import aiofiles
from aiohttp import ClientSession, ClientTimeout
from streetlevel import streetview

import asyncio
import csv
import json
import math
from pathlib import Path
import os

# %%
def unique_latlon(latlons: list[list[float]]) -> list[list[float]]:
    unique_latlons = set()
    for latlon in latlons:
        unique_latlons.add(tuple(latlon))
    return [list(x) for x in unique_latlons]

def depthmap_to_xyz(depthmap: list[list[float]],
                    xrange: tuple[float, float] = (-1.0, 1.0), yrange: tuple[float, float] = (-1.0, 1.0),
                    heading: float = 0, rfilter=math.inf) -> list[list[float]]:
    pi = math.pi
    sin = math.sin
    cos = math.cos
    output = []
    width = len(depthmap[0])
    height = len(depthmap)
    x0 = xrange[0]
    dx = xrange[1] - x0
    y0 = yrange[0]
    dy = yrange[1] - y0
    h = -heading
    for i in range(height):
        for j in range(width):
            r = depthmap[i][j]
            if r > rfilter:
                continue
            xnorm = ((j + 0.5) / width) * dx + x0
            ynorm = ((i + 0.5) / height) * dy + y0
            theta = -pi * xnorm
            phi = -pi / 2 * ynorm
            cartesian = [[-r * sin(h + theta) * cos(phi)],
                         [r * cos(h + theta) * cos(phi)],
                         [r * sin(phi)]]
            output.append([cartesian[0][0], cartesian[1][0], cartesian[2][0]])
    return output

# %%
async def find_pano_id(session, lat, lon, radius=50):
    try:
        return await streetview.find_panorama_async(lat, lon, session, radius=radius)
    except Exception as e:
        print(f"find_pano_id, ({lat}, {lon}): e")
        return None

async def find_pano_depth(session, panoid):
    try:
        return await streetview.find_panorama_by_id_async(panoid, session, download_depth=True)
    except Exception as e:
        print(f"find_pano_depth, ({panoid}): e")
        return None
    
async def find_pano_full(session, lat, lon, radius=50):
    base_pano = await find_pano_id(session, lat, lon, radius)
    if base_pano:
        return await find_pano_depth(session, base_pano.id)
    else:
        return None

async def save_pano_point_cloud(target_dir, pano_dir, point_cloud_dir, lat, lon, session, csv_writer):
    pano = await find_pano_full(session, lat, lon)
    if pano and pano.depth and pano.heading and pano.elevation:
        try:
            image = await streetview.get_panorama_async(pano, session, zoom=0)
            point_cloud = await asyncio.to_thread(depthmap_to_xyz, pano.depth.data[:,::-1], heading=pano.heading, rfilter=60)
            await csv_writer.writerow([pano.id, pano.lat, pano.lon, pano.elevation])
            await asyncio.to_thread(image.save, os.path.join(target_dir, pano_dir, f"{pano.id}.jpg"))
            async with aiofiles.open(os.path.join(target_dir, point_cloud_dir, f"{pano.id}.json"), mode='w') as fp:
                await fp.write(json.dumps(point_cloud))
        except Exception as e:
            print(f"save_pano_point_cloud, {pano.id}: e")

async def main(latlons, target_dir, pano_dir, point_cloud_dir, log_filename):
    Path(os.path.join(target_dir, pano_dir)).mkdir(parents=True, exist_ok=True)
    Path(os.path.join(target_dir, point_cloud_dir)).mkdir(parents=True, exist_ok=True)
    async with ClientSession() as session:
        async with aiofiles.open(os.path.join(target_dir, log_filename), mode='w+') as fp:
            csv_writer = aiocsv.AsyncWriter(fp)
            await csv_writer.writerow(["id", "lat", "lon", "elevation"])
            tasks = [save_pano_point_cloud(target_dir, pano_dir, point_cloud_dir, latlon[0], latlon[1], session, csv_writer) for latlon in latlons]
            await asyncio.gather(*tasks)

# %%
input_latlons = []
with open(os.path.join(target_dir, input_latlons_fp), 'r') as fp:
    input_latlons = json.load(fp)
input_latlons = unique_latlon(input_latlons)

await main(input_latlons, target_dir, pano_dir, point_cloud_dir, log_filename)
# Out:
# find_pano_depth, (EH0KBgr7HPM2O1rd-t67Ig): e
# find_pano_depth, (VTQz6NTFgqshz5bMNT9PtQ): e
# find_pano_depth, (TTMg3SOBxTasR2OvCzPZxw): e
# find_pano_depth, (Eno-NZ-Qk05HllVKlJ6JkQ): e
# ---------------------------------------------------------------------------
# ServerDisconnectedError                   Traceback (most recent call last)
# Cell In[5], line 6
#       3     input_latlons = json.load(fp)
#       4 input_latlons = unique_latlon(input_latlons)
# ----> 6 await main(input_latlons, target_dir, pano_dir, point_cloud_dir, log_filename)
#
# Cell In[4], line 40, in main(latlons, target_dir, pano_dir, point_cloud_dir, log_filename)
#      38 await csv_writer.writerow(["id", "lat", "lon", "elevation"])
#      39 tasks = [save_pano_point_cloud(target_dir, pano_dir, point_cloud_dir, latlon[0], latlon[1], session, csv_writer) for latlon in latlons]
# ---> 40 await asyncio.gather(*tasks)
#
# Cell In[4], line 25, in save_pano_point_cloud(target_dir, pano_dir, point_cloud_dir, lat, lon, session, csv_writer)
#      23 pano = await find_pano_full(session, lat, lon)
#      24 if pano and pano.depth and pano.heading and pano.elevation:
# ---> 25     image = await streetview.get_panorama_async(pano, session, zoom=0)
#      26     point_cloud = await asyncio.to_thread(depthmap_to_xyz, pano.depth.data[:,::-1], heading=pano.heading, rfilter=60)
#      27     await csv_writer.writerow([pano.id, pano.lat, pano.lon, pano.elevation])
#
# File /usr/local/lib/python3.12/site-packages/streetlevel/streetview/streetview.py:171, in get_panorama_async(pano, session, zoom)
#     169 async def get_panorama_async(pano: StreetViewPanorama, session: ClientSession, zoom: int = 5) -> Image.Image:
#     170     zoom = _validate_get_panorama_params(pano, zoom)
# --> 171     return await get_equirectangular_panorama_async(
#     172         pano.image_sizes[zoom].x, pano.image_sizes[zoom].y,
#     173         pano.tile_size, _generate_tile_list(pano, zoom),
#     174         session)
#
# File /usr/local/lib/python3.12/site-packages/streetlevel/util.py:142, in get_equirectangular_panorama_async(width, height, tile_size, tile_list, session)
#     129 async def get_equirectangular_panorama_async(width: int, height: int, tile_size: Size,
#     130                                              tile_list: List[Tile],
#     131                                              session: ClientSession) -> Image.Image:
#     132     """
#     133     Downloads and stitches a tiled equirectangular panorama.
#     134
#    (...)
#     140     :return: The stitched panorama as PIL image.
#     141     """
# --> 142     tile_images = await download_tiles_async(tile_list, session)
#     143     stitched = stitch_equirectangular_tiles(tile_images, width, height, tile_size.x, tile_size.y)
#     144     return stitched
#
# File /usr/local/lib/python3.12/site-packages/streetlevel/util.py:213, in download_tiles_async(tile_list, session)
#     204 async def download_tiles_async(tile_list: List[Tile], session: ClientSession):
#     205     """
#     206     Downloads tiles to ``bytes``.
#     207
#    (...)
#     210     :return: A dictionary containing the images as ``bytes`` with the key ``(x, y)``.
#     211     """
# --> 213     images = await download_files_async([t.url for t in tile_list], session=session)
#     215     images_dict = {}
#     216     for i, tile in enumerate(tile_list):
#
# File /usr/local/lib/python3.12/site-packages/streetlevel/util.py:177, in download_files_async(urls, session)
#     174 session = session if session else ClientSession()
#     176 tasks = [session.get(url) for url in urls]
# --> 177 responses = await asyncio.gather(*tasks)
#     178 data = []
#     179 for response in responses:
#
# File /usr/local/lib/python3.12/site-packages/aiohttp/client.py:1342, in _BaseRequestContextManager.throw(self, *args, **kwargs)
#    1341 def throw(self, *args: Any, **kwargs: Any) -> "asyncio.Future[Any]":
# -> 1342     return self._coro.throw(*args, **kwargs)
#
# File /usr/local/lib/python3.12/site-packages/aiohttp/client.py:686, in ClientSession._request(self, method, str_or_url, params, data, json, cookies, headers, skip_auto_headers, auth, allow_redirects, max_redirects, compress, chunked, expect100, raise_for_status, read_until_eof, proxy, proxy_auth, timeout, verify_ssl, fingerprint, ssl_context, ssl, server_hostname, proxy_headers, trace_request_ctx, read_bufsize, auto_decompress, max_line_size, max_field_size)
#     684 resp = await req.send(conn)
#     685 try:
# --> 686     await resp.start(conn)
#     687 except BaseException:
#     688     resp.close()
#
# File /usr/local/lib/python3.12/site-packages/aiohttp/client_reqrep.py:1022, in ClientResponse.start(self, connection)
#    1020 try:
#    1021     protocol = self._protocol
# -> 1022     message, payload = await protocol.read()  # type: ignore[union-attr]
#    1023 except http.HttpProcessingError as exc:
#    1024     raise ClientResponseError(
#    1025         self.request_info,
#    1026         self.history,
#    (...)
#    1029         headers=exc.headers,
#    1030     ) from exc
#
# File /usr/local/lib/python3.12/site-packages/aiohttp/streams.py:643, in DataQueue.read(self)
#     641 self._waiter = self._loop.create_future()
#     642 try:
# --> 643     await self._waiter
#     644 except (asyncio.CancelledError, asyncio.TimeoutError):
#     645     self._waiter = None
#
# ServerDisconnectedError: Server disconnected
# find_pano_depth, (nPkCJIeUvkV55ROfwUto8g): e
# find_pano_depth, (TM7TQLzwONFstjQJEYw70w): e
# find_pano_depth, (1tWox9639W2KRHVxW45jRA): e
# find_pano_id, (1.326071, 103.842835): e
# find_pano_depth, (SRH5-M85aXIq3pYjmRyT1Q): e
# find_pano_depth, (q4jz2AOoJzMAtSMNMrThnw): e
# find_pano_depth, (4nSZ_hUGaBZE-8-zgtt3DQ): e
# find_pano_id, (1.334116, 103.885599): e
# find_pano_depth, (eogFXOp0BY9UbFVJrvgW9Q): e
# find_pano_id, (1.361908, 103.966869): e
# find_pano_id, (1.356706, 103.948468): e
# find_pano_id, (1.388118, 103.834107): e
# find_pano_id, (1.322161, 103.812939): e
# find_pano_id, (1.386744, 103.907288): e
# find_pano_id, (1.32236, 103.875477): e
# find_pano_depth, (wEq_LD5zb61EaZvu7YS0pw): e
# find_pano_depth, (cjqcFcgffrGv4ttLVZIPAw): e
# find_pano_id, (1.338752, 103.892338): e
# find_pano_id, (1.383716, 103.867723): e
# find_pano_id, (1.295744, 103.774642): e
# find_pano_id, (1.345765, 103.942356): e
# find_pano_id, (1.316608, 103.862359): e
# find_pano_depth, (1YFsg-_jfOlfHWdclcdL1Q): e
# find_pano_depth, (GRoI01EMBbvkzzM2TPLKEQ): e
# find_pano_depth, (VXCisKIQmMBQmE_0EYYBnw): e
# find_pano_depth, (qHLPyuGAo8hoCyVAqdm99A): e
# find_pano_depth, (1y-Iq9tOrzKADyguV737eg): e
# find_pano_depth, (hCcRt1khNMYorJI8L1_ffw): e
# find_pano_depth, (lj6RD4Ck0QYOgQ4Khn8Lbw): e
# find_pano_id, (1.318305, 103.874369): e
# find_pano_id, (1.331498, 103.853434): e
# find_pano_depth, (XIhRLX-QyOf8iCqXlO72WQ): e
# find_pano_id, (1.302076, 103.786986): e
# find_pano_id, (1.302327, 103.859705): e
# find_pano_id, (1.296393, 103.788921): e
# find_pano_id, (1.427278, 103.846274): e
# find_pano_id, (1.305609, 103.799149): e
# find_pano_depth, (jhmiQigY0uXKIExHqMb58w): e
# find_pano_id, (1.335863, 103.940282): e
# find_pano_id, (1.417324, 103.801791): e
# find_pano_depth, (fVyo7mn4LGQFzHc3225wdA): e
# find_pano_depth, (nPkSwrsWFHkmT_D4DQkpZg): e
# find_pano_id, (1.32582, 103.796887): e
# find_pano_depth, (WzN3hBCyaTGPTnWdFXk2oA): e
# find_pano_depth, (HHFJ7GZzlVPvPgkFHTtzzw): e
# find_pano_id, (1.396274, 103.907805): e
# find_pano_depth, (IgvnP43euTl653ZXwgl6kg): e
# find_pano_depth, (vAyyl4Z3mplO5fwJ-2EjVQ): e
# find_pano_id, (1.328606, 103.874714): e
# find_pano_id, (1.3126, 103.90932): e
# find_pano_id, (1.297199, 103.875841): e
# find_pano_id, (1.306053, 103.786959): e
# find_pano_depth, (EAl4FF74-UQy5x_OZe0FRA): e
# find_pano_id, (1.310931, 103.871269): e
# find_pano_id, (1.400793, 103.896452): e
# find_pano_depth, (pTx58_-CoHFnYrU10FnUcA): e
# find_pano_depth, (oUwHlUFruo_rC9ois1rdKw): e
# find_pano_depth, (FbFyLWcI7cyi2VJ23GuuFw): e
# find_pano_depth, (yI7Vf9bkF-vb20DGN01z5A): e
# find_pano_id, (1.310719, 103.946582): e
# find_pano_id, (1.44255, 103.826092): e
# find_pano_id, (1.363751, 104.002639): e
# find_pano_depth, (bMed16lkHGV03T-7FQuLuA): e
# find_pano_id, (1.308026, 103.894742): e
# find_pano_id, (1.328708, 103.750288): e
# find_pano_id, (1.311567, 103.830776): e
# find_pano_id, (1.285546, 103.812495): e
# find_pano_id, (1.310413, 103.826019): e
# find_pano_depth, (Iurh4rlsoQOaMQWmeKO7rQ): e
# find_pano_id, (1.360498, 103.763292): e
# find_pano_id, (1.302785, 103.850893): e
# find_pano_depth, (bl7NjVEl4pz0CWKFOftlfA): e
# find_pano_id, (1.313751, 103.834137): e
# find_pano_id, (1.372481, 103.853586): e
# find_pano_id, (1.318368, 103.798692): e
# find_pano_id, (1.356857, 103.771326): e
# find_pano_id, (1.28742, 103.81786): e
# find_pano_id, (1.326232, 103.929804): e
# find_pano_id, (1.387712, 103.902077): e
# find_pano_id, (1.317434, 103.841653): e
# find_pano_id, (1.392025, 103.903277): e
# find_pano_id, (1.323062, 103.88735): e
# find_pano_id, (1.29425, 103.843448): e
# find_pano_id, (1.342262, 103.782258): e
# find_pano_id, (1.297583, 103.859306): e
# find_pano_id, (1.323568, 103.928156): e
# find_pano_id, (1.334906, 103.894403): e
# find_pano_id, (1.375138, 103.921308): e
# find_pano_id, (1.341913, 103.957813): e
# find_pano_id, (1.403559, 103.818075): e
# find_pano_id, (1.362616, 103.966515): e
# find_pano_id, (1.331651, 103.78841): e
# find_pano_id, (1.340338, 103.770022): e
# find_pano_id, (1.377507, 103.868583): e
# find_pano_id, (1.37515, 103.847845): e
# find_pano_id, (1.308958, 103.934047): e
# find_pano_id, (1.321029, 103.849465): e
# find_pano_id, (1.284965, 103.796148): e
# find_pano_id, (1.308506, 103.935113): e
# find_pano_id, (1.30735, 103.815613): e
# find_pano_id, (1.354236, 103.941454): e
# find_pano_id, (1.371782, 103.862738): e
# find_pano_id, (1.38432, 103.745309): e
# find_pano_id, (1.325692, 103.740537): e
# find_pano_id, (1.333139, 103.795821): e
# find_pano_id, (1.300528, 103.88541): e
# find_pano_id, (1.263947, 103.823818): e
# find_pano_id, (1.376813, 103.938423): e
# find_pano_id, (1.333212, 103.889248): e
# find_pano_id, (1.366395, 103.769811): e
# find_pano_id, (1.302062, 103.850012): e
# find_pano_id, (1.300012, 103.792352): e
# find_pano_id, (1.334282, 103.899735): e
# find_pano_id, (1.378388, 103.765871): e
# find_pano_id, (1.321771, 103.878402): e
# find_pano_id, (1.365474, 103.880941): e
# find_pano_id, (1.323238, 103.784115): e
# find_pano_id, (1.287404, 103.861455): e
# find_pano_id, (1.372481, 103.83683): e
# find_pano_id, (1.423954, 103.82962): e
# find_pano_id, (1.380255, 103.942799): e
# find_pano_id, (1.31143, 103.942133): e
# find_pano_id, (1.31376, 103.877363): e
# find_pano_id, (1.331783, 103.941858): e
# find_pano_id, (1.337437, 103.907598): e
# find_pano_id, (1.391405, 103.865481): e
# find_pano_id, (1.32604, 103.897081): e
# find_pano_id, (1.321882, 103.782206): e
# find_pano_id, (1.309855, 103.886909): e
# find_pano_id, (1.323601, 103.809341): e
# find_pano_id, (1.312885, 103.839342): e
# find_pano_id, (1.320983, 103.847586): e
# find_pano_id, (1.382568, 103.929546): e
# find_pano_id, (1.372625, 103.83318): e
# find_pano_id, (1.374529, 103.775247): e
# find_pano_id, (1.282772, 103.817094): e
# find_pano_id, (1.290955, 103.787415): e
# find_pano_id, (1.369404, 103.960505): e
# find_pano_id, (1.364925, 103.971217): e
# find_pano_id, (1.307934, 103.894342): e
# find_pano_id, (1.289524, 103.861097): e
# find_pano_id, (1.351822, 103.832278): e
# find_pano_id, (1.379524, 103.747818): e
# find_pano_id, (1.39505, 103.904115): e
# find_pano_id, (1.330661, 103.790094): e
# find_pano_id, (1.379971, 103.893494): e
# find_pano_id, (1.274019, 103.819812): e
# find_pano_id, (1.348987, 103.770432): e
# find_pano_id, (1.392735, 103.89524): e
# find_pano_id, (1.371156, 103.832787): e
# find_pano_id, (1.359156, 103.869184): e
# find_pano_id, (1.325437, 103.768526): e
# find_pano_id, (1.382735, 103.871838): e
# find_pano_id, (1.330937, 103.78612): e
# find_pano_id, (1.329699, 103.791783): e
# find_pano_id, (1.381141, 103.828652): e
# find_pano_id, (1.304938, 103.815803): e
# find_pano_id, (1.328424, 103.922734): e
# find_pano_id, (1.284435, 103.849006): e
# find_pano_id, (1.335055, 103.736042): e
# find_pano_id, (1.307418, 103.900734): e
# find_pano_id, (1.326061, 103.842736): e
# find_pano_id, (1.403724, 103.910596): e
# find_pano_id, (1.274011, 103.806373): e
# find_pano_id, (1.365851, 103.745854): e
# find_pano_id, (1.322764, 103.917366): e
# find_pano_id, (1.380171, 103.866766): e
# find_pano_id, (1.385561, 103.883992): e
# find_pano_id, (1.334434, 103.777961): e
# find_pano_id, (1.370341, 103.971248): e
# find_pano_id, (1.342754, 103.732534): e
# find_pano_id, (1.332545, 103.712026): e
# find_pano_id, (1.373573, 103.862896): e
# find_pano_id, (1.324963, 103.974748): e
# find_pano_id, (1.373835, 103.935761): e
# find_pano_id, (1.316539, 103.927552): e
# find_pano_id, (1.390931, 103.869045): e
# find_pano_id, (1.317954, 103.788922): e
# find_pano_id, (1.30881, 103.789512): e
# find_pano_id, (1.314355, 103.767617): e
# find_pano_id, (1.318693, 103.810103): e
# find_pano_id, (1.425386, 103.857006): e
# find_pano_id, (1.325237, 103.923784): e
# find_pano_id, (1.324602, 103.82901): e
# find_pano_id, (1.337101, 103.845372): e
# find_pano_id, (1.314706, 103.959777): e
# find_pano_id, (1.346694, 103.865636): e
# find_pano_id, (1.302627, 103.914273): e
# find_pano_id, (1.310582, 103.941023): e
# find_pano_id, (1.38751, 103.904735): e
# find_pano_id, (1.346528, 103.924154): e
# find_pano_id, (1.342373, 103.947752): e
# find_pano_id, (1.368503, 103.747969): e
# find_pano_id, (1.366919, 103.875365): e
# find_pano_id, (1.379845, 103.959963): e
# find_pano_id, (1.327898, 103.769489): e
# find_pano_id, (1.352157, 103.959999): e
# find_pano_id, (1.315163, 103.904822): e
# find_pano_id, (1.305922, 103.800767): e
# find_pano_id, (1.28899, 103.853134): e
# find_pano_id, (1.296039, 103.810377): e
# find_pano_id, (1.33369, 103.790368): e
# find_pano_id, (1.293249, 103.799082): e
# find_pano_id, (1.293146, 103.80232): e
# find_pano_id, (1.367265, 103.952242): e
# find_pano_id, (1.363541, 103.883688): e
# find_pano_id, (1.347186, 103.871089): e
# find_pano_id, (1.293806, 103.780748): e
# find_pano_id, (1.381784, 103.886909): e
# find_pano_id, (1.326163, 103.730369): e
# find_pano_id, (1.4097, 103.807682): e
# find_pano_id, (1.372402, 103.970664): e
# find_pano_id, (1.372258, 103.84834): e
# find_pano_id, (1.344413, 103.938393): e
# find_pano_id, (1.415104, 103.904721): e
# find_pano_id, (1.386799, 103.82961): e
# find_pano_id, (1.323349, 103.866964): e
# find_pano_id, (1.328968, 103.71947): e
# find_pano_id, (1.40083, 103.863267): e
# find_pano_id, (1.365861, 103.952237): e
# find_pano_id, (1.299119, 103.849148): e
# find_pano_id, (1.266082, 103.824822): e
# find_pano_id, (1.30641, 103.891551): e
# find_pano_id, (1.319879, 103.728075): e
# find_pano_id, (1.317315, 103.876623): e
# find_pano_id, (1.313744, 103.850764): e
# find_pano_id, (1.360744, 103.762784): e
# find_pano_id, (1.360222, 103.758444): e
# find_pano_id, (1.384482, 103.900355): e
# find_pano_id, (1.344204, 103.879148): e
# find_pano_id, (1.334952, 103.816775): e
# find_pano_id, (1.354997, 103.895469): e
# find_pano_id, (1.312512, 103.922064): e
# find_pano_id, (1.394972, 103.873391): e
# find_pano_id, (1.309464, 103.80034): e
# find_pano_id, (1.330573, 103.913374): e
# find_pano_id, (1.312024, 103.750711): e
# find_pano_id, (1.319729, 103.747406): e
# find_pano_id, (1.333808, 103.811859): e
# find_pano_id, (1.378753, 103.874889): e
# find_pano_id, (1.310269, 103.945953): e
# find_pano_id, (1.33407, 103.794246): e
# find_pano_id, (1.313727, 103.870256): e
# find_pano_id, (1.354499, 103.838052): e
# find_pano_id, (1.38308, 103.873134): e
# find_pano_id, (1.33008, 103.885945): e
# find_pano_id, (1.387315, 103.873041): e
# find_pano_id, (1.333191, 103.779404): e
# find_pano_id, (1.373098, 103.937458): e
# find_pano_id, (1.301703, 103.820659): e
# find_pano_id, (1.305064, 103.890179): e
# find_pano_id, (1.304852, 103.863348): e
# find_pano_id, (1.355705, 103.923763): e
# find_pano_id, (1.331805, 103.909055): e
# find_pano_id, (1.271374, 103.811268): e
# find_pano_id, (1.329192, 103.818602): e
# find_pano_id, (1.399707, 103.817479): e
# find_pano_id, (1.341243, 103.913972): e
# find_pano_id, (1.322628, 103.911675): e
# find_pano_id, (1.401905, 103.812185): e
# find_pano_id, (1.301997, 103.769339): e
# find_pano_id, (1.391799, 103.890273): e
# find_pano_id, (1.367889, 103.829235): e
# find_pano_id, (1.33247, 103.9528): e
# find_pano_id, (1.351033, 103.956482): e
# find_pano_id, (1.351841, 103.957405): e
# find_pano_id, (1.319236, 103.768289): e
# find_pano_id, (1.395738, 103.912529): e
# find_pano_id, (1.391796, 103.907691): e
# find_pano_id, (1.336851, 103.78063): e
# find_pano_id, (1.373031, 103.839494): e
# find_pano_id, (1.310276, 103.788233): e
# find_pano_id, (1.370104, 103.88331): e
# find_pano_id, (1.372671, 103.911827): e
# find_pano_id, (1.313006, 103.760076): e
# find_pano_id, (1.35772, 103.880395): e
# find_pano_id, (1.353749, 103.956525): e
# find_pano_id, (1.322058, 103.820355): e
# find_pano_id, (1.374986, 103.938195): e
# find_pano_id, (1.370844, 103.879066): e
# find_pano_id, (1.284862, 103.83601): e
# find_pano_id, (1.377552, 103.975821): e
# find_pano_id, (1.375143, 103.832049): e
# find_pano_id, (1.278745, 103.794392): e
# find_pano_id, (1.327279, 103.922669): e
# find_pano_id, (1.301279, 103.791251): e
# find_pano_id, (1.30314, 103.815648): e
# find_pano_id, (1.31332, 103.928863): e
# find_pano_id, (1.346957, 103.749495): e
# find_pano_id, (1.37324, 103.826486): e
# find_pano_id, (1.338652, 103.886841): e
# find_pano_id, (1.320991, 103.952549): e
# find_pano_id, (1.42289, 103.851027): e
# find_pano_id, (1.379711, 103.776109): e
# find_pano_id, (1.336503, 103.905976): e
# find_pano_id, (1.297802, 103.84637): e
# find_pano_id, (1.325321, 103.908945): e
# find_pano_id, (1.373885, 103.955278): e
# find_pano_id, (1.386363, 103.85921): e
# find_pano_id, (1.282721, 103.819655): e
# find_pano_id, (1.391437, 103.834947): e
# find_pano_id, (1.410579, 103.900318): e
# find_pano_id, (1.291483, 103.796663): e
# find_pano_id, (1.32391, 103.715508): e
# find_pano_id, (1.3125, 103.893098): e
# find_pano_id, (1.360031, 103.925472): e
# find_pano_id, (1.312409, 103.921825): e
# find_pano_id, (1.343768, 103.738305): e
# find_pano_id, (1.296856, 103.861176): e
# find_pano_id, (1.310044, 103.789113): e
# find_pano_id, (1.353159, 103.841226): e
# find_pano_id, (1.362196, 103.82963): e
# find_pano_id, (1.339865, 103.856805): e
# find_pano_id, (1.369671, 103.970397): e
# find_pano_id, (1.317909, 103.866059): e
# find_pano_id, (1.302565, 103.798346): e
# find_pano_id, (1.367089, 103.959071): e
# find_pano_id, (1.395675, 103.86369): e
# find_pano_id, (1.413247, 103.839474): e
# find_pano_id, (1.356186, 103.870569): e
# find_pano_id, (1.279288, 103.870175): e
# find_pano_id, (1.346264, 103.952394): e
# find_pano_id, (1.317325, 103.791218): e
# find_pano_id, (1.307529, 103.876617): e
# find_pano_id, (1.345748, 103.882015): e
# find_pano_id, (1.346831, 103.948565): e
# find_pano_id, (1.377335, 103.739044): e
# find_pano_id, (1.341892, 103.937248): e
# find_pano_id, (1.346166, 103.875943): e
# find_pano_id, (1.385878, 103.905164): e
# find_pano_id, (1.3495, 103.964273): e
# find_pano_id, (1.337766, 103.980427): e
# find_pano_id, (1.328022, 103.94906): e
# find_pano_id, (1.356498, 103.93802): e
# find_pano_id, (1.415327, 103.904089): e
# find_pano_id, (1.291601, 103.843418): e
# find_pano_id, (1.321451, 103.72011): e
# find_pano_id, (1.309794, 103.877328): e
# find_pano_id, (1.304518, 103.770649): e
# find_pano_id, (1.314383, 103.80458): e
# find_pano_id, (1.382089, 103.974784): e
# find_pano_id, (1.345659, 103.948824): e
# find_pano_id, (1.375207, 103.901151): e
# find_pano_id, (1.325773, 103.768688): e
# find_pano_id, (1.352577, 103.899983): e
# find_pano_id, (1.325888, 103.793962): e
# find_pano_id, (1.40258, 103.896759): e
# find_pano_id, (1.327493, 103.813725): e
# find_pano_id, (1.315703, 103.834948): e
# find_pano_id, (1.352549, 103.837064): e
# find_pano_id, (1.364317, 103.774219): e
# find_pano_id, (1.395314, 103.873766): e
# find_pano_id, (1.329464, 103.918077): e
# find_pano_id, (1.319288, 103.918373): e
# find_pano_id, (1.35242, 103.943214): e
# find_pano_id, (1.344543, 103.770082): e
# find_pano_id, (1.328648, 103.851222): e
# find_pano_id, (1.369059, 103.893627): e
# find_pano_id, (1.413347, 103.862185): e
# find_pano_id, (1.386621, 103.935169): e
# find_pano_id, (1.360068, 103.838073): e
# find_pano_id, (1.326595, 103.710949): e
# find_pano_id, (1.311766, 103.895501): e
# find_pano_id, (1.338147, 103.804459): e
# find_pano_id, (1.376849, 103.91377): e
# find_pano_id, (1.319061, 103.916794): e
# find_pano_id, (1.286479, 103.838865): e
# find_pano_id, (1.320041, 103.902296): e
# find_pano_id, (1.308085, 103.859874): e
# find_pano_id, (1.337352, 103.980141): e
# find_pano_id, (1.345125, 103.765053): e
# find_pano_id, (1.372779, 104.004572): e
# find_pano_id, (1.330356, 103.843302): e
# find_pano_id, (1.273583, 103.830579): e
# find_pano_id, (1.323934, 103.729424): e
# find_pano_id, (1.340409, 103.897732): e
# find_pano_id, (1.33801, 103.734208): e
# find_pano_id, (1.351219, 103.852477): e
# find_pano_id, (1.420836, 103.848892): e
# find_pano_id, (1.372362, 103.828519): e
# find_pano_id, (1.347488, 103.88126): e
# find_pano_id, (1.346232, 103.945562): e
# find_pano_id, (1.284736, 103.805528): e
# find_pano_id, (1.440672, 103.824749): e
# find_pano_id, (1.347424, 103.946583): e
# find_pano_id, (1.336051, 103.965482): e
# find_pano_id, (1.371691, 103.753277): e
# find_pano_id, (1.341212, 103.889214): e
# find_pano_id, (1.33399, 103.908644): e
# find_pano_id, (1.336657, 103.954318): e
# find_pano_id, (1.347511, 103.865649): e
# find_pano_id, (1.335999, 103.92935): e
# find_pano_id, (1.323135, 103.769555): e
# find_pano_id, (1.321533, 103.885936): e
# find_pano_id, (1.37239, 103.873794): e
# find_pano_id, (1.322969, 103.857288): e
# find_pano_id, (1.372173, 103.87182): e
# find_pano_id, (1.346318, 103.960642): e
# find_pano_id, (1.325118, 103.925753): e
# find_pano_id, (1.32645, 103.810318): e
# find_pano_id, (1.350059, 103.957465): e
# find_pano_id, (1.316759, 103.798152): e
# find_pano_id, (1.268847, 103.801938): e
# find_pano_id, (1.325947, 103.856455): e
# find_pano_id, (1.43641, 103.838319): e
# find_pano_id, (1.321977, 103.876358): e
# find_pano_id, (1.295053, 103.85094): e
# find_pano_id, (1.348996, 103.996408): e
# find_pano_id, (1.290126, 103.82602): e
# find_pano_id, (1.354346, 103.896553): e
# find_pano_id, (1.350515, 103.935697): e
# find_pano_id, (1.373517, 103.895885): e
# find_pano_id, (1.321983, 103.719944): e
# find_pano_id, (1.356909, 103.965177): e
# find_pano_id, (1.308979, 103.762252): e
# find_pano_id, (1.388425, 103.87399): e
# find_pano_id, (1.31759, 103.771608): e
# find_pano_id, (1.329895, 103.867525): e
# find_pano_id, (1.346007, 103.774757): e
# find_pano_id, (1.359377, 103.869322): e
# find_pano_id, (1.341563, 103.85514): e
# find_pano_id, (1.299691, 103.836799): e
# find_pano_id, (1.332267, 103.747394): e
# find_pano_id, (1.374268, 103.967176): e
# find_pano_id, (1.307438, 103.777898): e
# find_pano_id, (1.325756, 103.896023): e
# find_pano_id, (1.380396, 103.933668): e
# find_pano_id, (1.297698, 103.844317): e
# find_pano_id, (1.300679, 103.840941): e
# find_pano_id, (1.37923, 103.974435): e
# find_pano_id, (1.38154, 103.837014): e
# find_pano_id, (1.298072, 103.831811): e
# find_pano_id, (1.376076, 103.932675): e
# find_pano_id, (1.323619, 103.787): e
# find_pano_id, (1.373416, 103.91217): e
# find_pano_id, (1.313486, 103.804245): e
# find_pano_id, (1.350675, 103.886425): e
# find_pano_id, (1.333969, 103.914355): e
# find_pano_id, (1.382661, 103.761104): e
# find_pano_id, (1.310557, 103.820467): e
# find_pano_id, (1.37105, 103.858527): e
# find_pano_id, (1.318083, 103.847145): e
# find_pano_id, (1.362009, 103.86419): e
# find_pano_id, (1.320126, 103.92311): e
# find_pano_id, (1.383574, 103.772181): e
# find_pano_id, (1.389942, 103.856442): e
# find_pano_id, (1.300033, 103.855308): e
# find_pano_id, (1.328902, 103.884818): e
# find_pano_id, (1.267916, 103.816138): e
# find_pano_id, (1.339036, 103.781952): e
# find_pano_id, (1.30931, 103.909052): e
# find_pano_id, (1.304478, 103.851154): e
# find_pano_id, (1.323407, 103.883307): e
# find_pano_id, (1.35534, 103.849346): e
# find_pano_id, (1.406334, 103.899199): e
# find_pano_id, (1.308887, 103.884245): e
# find_pano_id, (1.339955, 103.78498): e
# find_pano_id, (1.284733, 103.815523): e
# find_pano_id, (1.370757, 103.861596): e
# find_pano_id, (1.386518, 103.740778): e
# find_pano_id, (1.321797, 103.888875): e
# find_pano_id, (1.315475, 103.943138): e
# find_pano_id, (1.386634, 103.87219): e
# find_pano_id, (1.308347, 103.838202): e
# find_pano_id, (1.390098, 103.884862): e
# find_pano_id, (1.310708, 103.804485): e
# find_pano_id, (1.320618, 103.914624): e
# find_pano_id, (1.41996, 103.837975): e
# find_pano_id, (1.328138, 103.820182): e
# find_pano_id, (1.313946, 103.889211): e
# find_pano_id, (1.341354, 103.870581): e
# find_pano_id, (1.327953, 103.94147): e
# find_pano_id, (1.333821, 103.80132): e
# find_pano_id, (1.304533, 103.798379): e
# find_pano_id, (1.275378, 103.819651): e
# find_pano_id, (1.313147, 103.887407): e
# find_pano_id, (1.365357, 103.750356): e
# find_pano_id, (1.312279, 103.812834): e
# find_pano_id, (1.383186, 104.001069): e
# find_pano_id, (1.412631, 103.830893): e
# find_pano_id, (1.28619, 103.79728): e
# find_pano_id, (1.322838, 103.946002): e
# find_pano_id, (1.265879, 103.822346): e
# find_pano_id, (1.377787, 103.892872): e
# find_pano_id, (1.395891, 103.894775): e
# find_pano_id, (1.310538, 103.947391): e
# find_pano_id, (1.312304, 103.894457): e
# find_pano_id, (1.298617, 103.800331): e
# find_pano_id, (1.368405, 103.897018): e
# find_pano_id, (1.351567, 103.753629): e
# find_pano_id, (1.321074, 103.793745): e
# find_pano_id, (1.359724, 103.969985): e
# find_pano_id, (1.308599, 103.8837): e
# find_pano_id, (1.340218, 103.967765): e
# find_pano_id, (1.323047, 103.840692): e
# find_pano_id, (1.314686, 103.821776): e
# find_pano_id, (1.329815, 103.883514): e
# find_pano_id, (1.354221, 103.968356): e
# find_pano_id, (1.38893, 103.998456): e
# find_pano_id, (1.325354, 103.973605): e
# find_pano_id, (1.322936, 103.737459): e
# find_pano_id, (1.367032, 103.862335): e
# find_pano_id, (1.31481, 103.906008): e
# find_pano_id, (1.345973, 103.845149): e
# find_pano_id, (1.328273, 103.83892): e
# find_pano_id, (1.428742, 103.832856): e
# find_pano_id, (1.385636, 103.74054): e
# find_pano_id, (1.296407, 103.787408): e
# find_pano_id, (1.301691, 103.773264): e
# find_pano_id, (1.33424, 103.858025): e
# find_pano_id, (1.396447, 103.852056): e
# find_pano_id, (1.34865, 103.739558): e
# find_pano_id, (1.314239, 103.840327): e
# find_pano_id, (1.314577, 103.87329): e
# find_pano_id, (1.341991, 103.839439): e
# find_pano_id, (1.391379, 103.891524): e
# find_pano_id, (1.327658, 103.932045): e
# find_pano_id, (1.31331, 103.955344): e
# find_pano_id, (1.355737, 103.864867): e
# find_pano_id, (1.348308, 103.745733): e
# find_pano_id, (1.342088, 103.779697): e
# find_pano_id, (1.374237, 103.826565): e
# find_pano_id, (1.394516, 103.916245): e
# find_pano_id, (1.338439, 103.940805): e
# find_pano_id, (1.320772, 103.841246): e
# find_pano_id, (1.418242, 103.83636): e
# find_pano_id, (1.334609, 103.912337): e
# find_pano_id, (1.381336, 103.836186): e
# find_pano_id, (1.326109, 103.915766): e
# find_pano_id, (1.332529, 103.888019): e
# find_pano_id, (1.395687, 103.86387): e
# find_pano_id, (1.347942, 103.776441): e
# find_pano_id, (1.339705, 103.756327): e
# find_pano_id, (1.316936, 103.835968): e
# find_pano_id, (1.370489, 103.897453): e
# find_pano_id, (1.336692, 103.963151): e
# find_pano_id, (1.389672, 103.854392): e
# find_pano_id, (1.346983, 103.745623): e
# find_pano_id, (1.320329, 103.859251): e
# find_pano_id, (1.316073, 103.78902): e
# find_pano_id, (1.340085, 103.970113): e
# find_pano_id, (1.346536, 103.882162): e
# find_pano_id, (1.283802, 103.798078): e
# find_pano_id, (1.336457, 103.919731): e
# find_pano_id, (1.312083, 103.799862): e
# find_pano_id, (1.376342, 103.850602): e
# find_pano_id, (1.37464, 103.845101): e
# find_pano_id, (1.27427, 103.794308): e
# find_pano_id, (1.316804, 103.790623): e
# find_pano_id, (1.318712, 103.762997): e
# find_pano_id, (1.290923, 103.839493): e
# find_pano_id, (1.314845, 103.751072): e
# find_pano_id, (1.319093, 103.814926): e
# find_pano_id, (1.323277, 103.949507): e
# find_pano_id, (1.306592, 103.831069): e
# find_pano_id, (1.366724, 103.8586): e
# find_pano_id, (1.419267, 103.840246): e
# find_pano_id, (1.415633, 103.803792): e
# find_pano_id, (1.321167, 103.759445): e
# find_pano_id, (1.320116, 103.755268): e
# find_pano_id, (1.286622, 103.8103): e
# find_pano_id, (1.37317, 103.974206): e
# find_pano_id, (1.329477, 103.94902): e
# find_pano_id, (1.384834, 103.823829): e
# find_pano_id, (1.298427, 103.830061): e
# find_pano_id, (1.311698, 103.954228): e
# find_pano_id, (1.311893, 103.834964): e
# find_pano_id, (1.315788, 103.78702): e
# find_pano_id, (1.353587, 103.83435): e
# find_pano_id, (1.301797, 103.837803): e
# find_pano_id, (1.30933, 103.909144): e
# find_pano_id, (1.352775, 103.93907): e
# find_pano_id, (1.366349, 103.974583): e
# find_pano_id, (1.38344, 103.879988): e
# find_pano_id, (1.340494, 103.723054): e
# find_pano_id, (1.336737, 103.757007): e
# find_pano_id, (1.345848, 103.759909): e
# find_pano_id, (1.380919, 103.850366): e
# find_pano_id, (1.39112, 103.851495): e
# find_pano_id, (1.369553, 103.963997): e
# find_pano_id, (1.393741, 103.903849): e
# find_pano_id, (1.339424, 103.940376): e
# find_pano_id, (1.403252, 103.870833): e
# find_pano_id, (1.360706, 103.830127): e
# find_pano_id, (1.294315, 103.773698): e
# find_pano_id, (1.347907, 103.924061): e
# find_pano_id, (1.324189, 103.76663): e
# find_pano_id, (1.371378, 103.751776): e
# find_pano_id, (1.354852, 103.866726): e
# find_pano_id, (1.345535, 103.894378): e
# find_pano_id, (1.33032, 103.88736): e
# find_pano_id, (1.330954, 103.741012): e
# find_pano_id, (1.328502, 103.84444): e
# find_pano_id, (1.398974, 103.898052): e
# find_pano_id, (1.343562, 103.960432): e
# find_pano_id, (1.352655, 103.887315): e
# find_pano_id, (1.306467, 103.874907): e
# find_pano_id, (1.3352, 103.759951): e
# find_pano_id, (1.347526, 103.92267): e
# find_pano_id, (1.366181, 103.875383): e
# find_pano_id, (1.396272, 103.899178): e
# find_pano_id, (1.312444, 103.957152): e
# find_pano_id, (1.359984, 103.851983): e
# find_pano_id, (1.300718, 103.789346): e
# find_pano_id, (1.352162, 103.959438): e
# find_pano_id, (1.386684, 103.864127): e
# find_pano_id, (1.376423, 103.859041): e
# find_pano_id, (1.318906, 103.939007): e
# find_pano_id, (1.356819, 103.874032): e
# find_pano_id, (1.322797, 103.900772): e
# find_pano_id, (1.274009, 103.846221): e
# find_pano_id, (1.387236, 103.839135): e
# find_pano_id, (1.323104, 103.892587): e
# find_pano_id, (1.332068, 103.918184): e
# find_pano_id, (1.367671, 103.865211): e
# find_pano_id, (1.378736, 103.765502): e
# find_pano_id, (1.327258, 103.952892): e
# find_pano_id, (1.303369, 103.838345): e
# find_pano_id, (1.381001, 103.897139): e
# find_pano_id, (1.320146, 103.727185): e
# find_pano_id, (1.321069, 103.784766): e
# find_pano_id, (1.377987, 103.741134): e
# find_pano_id, (1.35179, 103.953965): e
# find_pano_id, (1.380185, 103.839633): e
# find_pano_id, (1.33985, 103.942773): e
# find_pano_id, (1.383327, 103.840277): e
# find_pano_id, (1.285378, 103.832504): e
# find_pano_id, (1.385343, 103.846009): e
# find_pano_id, (1.284537, 103.793573): e
# find_pano_id, (1.362594, 103.878984): e
# find_pano_id, (1.318121, 103.747367): e
# find_pano_id, (1.377023, 103.928535): e
# find_pano_id, (1.35716, 103.839685): e
# find_pano_id, (1.37279, 103.895264): e
# find_pano_id, (1.357512, 103.895093): e
# find_pano_id, (1.317284, 103.780763): e
# find_pano_id, (1.363304, 103.829728): e
# find_pano_id, (1.386733, 103.826308): e
# find_pano_id, (1.331237, 103.741035): e
# find_pano_id, (1.35001, 103.835192): e
# find_pano_id, (1.387726, 103.848308): e
# find_pano_id, (1.276236, 103.861134): e
# find_pano_id, (1.354778, 103.832684): e
# find_pano_id, (1.428115, 103.838016): e
# find_pano_id, (1.393911, 103.820005): e
# find_pano_id, (1.354539, 103.924806): e
# find_pano_id, (1.379135, 103.850358): e
# find_pano_id, (1.287584, 103.854144): e
# find_pano_id, (1.346469, 103.736212): e
# find_pano_id, (1.350188, 103.770063): e
# find_pano_id, (1.334104, 103.720036): e
# find_pano_id, (1.332119, 103.889303): e
# find_pano_id, (1.322984, 103.800933): e
# find_pano_id, (1.375122, 103.864384): e
# find_pano_id, (1.322554, 103.749945): e
# find_pano_id, (1.353752, 103.752189): e
# find_pano_id, (1.32542, 103.894418): e
# find_pano_id, (1.335933, 103.798622): e
# find_pano_id, (1.321142, 103.765319): e
# find_pano_id, (1.396532, 103.844732): e
# find_pano_id, (1.423917, 103.849632): e
# find_pano_id, (1.362261, 103.887455): e
# find_pano_id, (1.358066, 103.96475): e
# find_pano_id, (1.381519, 103.764146): e
# find_pano_id, (1.386547, 103.863182): e
# find_pano_id, (1.348413, 103.946363): e
# find_pano_id, (1.335233, 103.805684): e
# find_pano_id, (1.391803, 103.901269): e
# find_pano_id, (1.315554, 103.836693): e
# find_pano_id, (1.305327, 103.876835): e
# find_pano_id, (1.310836, 103.899108): e
# find_pano_id, (1.353689, 103.886676): e
# find_pano_id, (1.315897, 103.833426): e
# find_pano_id, (1.345326, 103.850968): e
# find_pano_id, (1.311867, 103.893511): e
# find_pano_id, (1.348049, 103.759044): e
# find_pano_id, (1.375065, 103.876103): e
# find_pano_id, (1.295359, 103.888723): e
# find_pano_id, (1.37813, 103.744901): e
# find_pano_id, (1.331768, 103.942003): e
# find_pano_id, (1.32178, 103.806919): e
# find_pano_id, (1.320915, 103.73647): e
# find_pano_id, (1.347149, 103.892003): e
# find_pano_id, (1.339524, 103.743691): e
# find_pano_id, (1.348638, 103.953627): e
# find_pano_id, (1.32009, 103.8215): e
# find_pano_id, (1.384346, 103.828783): e
# find_pano_id, (1.276462, 103.840693): e
# find_pano_id, (1.33922, 103.84393): e
# find_pano_id, (1.392345, 103.852801): e
# find_pano_id, (1.33167, 103.806352): e
# find_pano_id, (1.315936, 103.769965): e
# find_pano_id, (1.324156, 103.884089): e
# find_pano_id, (1.308345, 103.760326): e
# find_pano_id, (1.320418, 103.875787): e
# find_pano_id, (1.371826, 103.879092): e
# find_pano_id, (1.379429, 103.96453): e
# find_pano_id, (1.378618, 103.88391): e
# find_pano_id, (1.386142, 103.758645): e
# find_pano_id, (1.392157, 103.853777): e
# find_pano_id, (1.310088, 103.930742): e
# find_pano_id, (1.303754, 103.810442): e
# find_pano_id, (1.322022, 103.90519): e
# find_pano_id, (1.38911, 103.902554): e
# find_pano_id, (1.351025, 103.845649): e
# find_pano_id, (1.368634, 103.887028): e
# find_pano_id, (1.397428, 103.87259): e
# find_pano_id, (1.308214, 103.938215): e
# find_pano_id, (1.343415, 103.937948): e
# find_pano_id, (1.326412, 103.929723): e
# find_pano_id, (1.269399, 103.828985): e
# find_pano_id, (1.311769, 103.794341): e
# find_pano_id, (1.372463, 103.83007): e
# find_pano_id, (1.33585, 103.80994): e
# find_pano_id, (1.30784, 103.794443): e
# find_pano_id, (1.285151, 103.81635): e
# find_pano_id, (1.302859, 103.772885): e
# find_pano_id, (1.375832, 103.853716): e
# find_pano_id, (1.389788, 103.749243): e
# find_pano_id, (1.294517, 103.827144): e
# find_pano_id, (1.339776, 103.785): e
# find_pano_id, (1.376475, 103.757886): e
# find_pano_id, (1.391121, 103.893638): e
# find_pano_id, (1.350523, 103.845845): e
# find_pano_id, (1.286683, 103.841539): e
# find_pano_id, (1.353916, 103.968007): e
# find_pano_id, (1.333332, 103.967166): e
# find_pano_id, (1.34064, 103.897375): e
# find_pano_id, (1.326756, 103.823786): e
# find_pano_id, (1.331466, 103.720318): e
# find_pano_id, (1.381092, 103.826738): e
# find_pano_id, (1.402736, 103.815748): e
# find_pano_id, (1.385716, 103.858646): e
# find_pano_id, (1.32479, 103.724141): e
# find_pano_id, (1.284006, 103.836967): e
# find_pano_id, (1.379419, 103.898072): e
# find_pano_id, (1.368513, 103.885488): e
# find_pano_id, (1.33379, 103.922291): e
# find_pano_id, (1.362218, 103.838788): e
# find_pano_id, (1.295904, 103.795565): e
# find_pano_id, (1.311533, 103.943116): e
# find_pano_id, (1.385121, 103.90491): e
# find_pano_id, (1.328829, 103.927343): e
# find_pano_id, (1.322275, 103.840234): e
# find_pano_id, (1.325737, 103.898972): e
# find_pano_id, (1.282505, 103.812302): e
# find_pano_id, (1.28766, 103.846127): e
# find_pano_id, (1.327486, 103.74513): e
# find_pano_id, (1.316348, 103.849675): e
# find_pano_id, (1.32783, 103.812492): e
# find_pano_id, (1.322935, 103.901406): e
# find_pano_id, (1.357911, 103.930562): e
# find_pano_id, (1.333789, 103.763125): e
# find_pano_id, (1.381777, 103.974967): e
# find_pano_id, (1.37342, 103.851832): e
# find_pano_id, (1.319301, 103.843048): e
# find_pano_id, (1.417178, 103.833181): e
# find_pano_id, (1.3598, 103.866516): e
# find_pano_id, (1.325441, 103.8642): e
# find_pano_id, (1.339683, 103.778397): e
# find_pano_id, (1.311218, 103.86245): e
# find_pano_id, (1.355353, 103.938875): e
# find_pano_id, (1.336177, 103.72668): e
# find_pano_id, (1.401771, 103.906784): e
# find_pano_id, (1.33814, 103.851198): e
# find_pano_id, (1.322718, 103.749431): e
# find_pano_id, (1.320186, 103.901329): e
# find_pano_id, (1.334254, 103.715317): e
# find_pano_id, (1.32994, 103.899459): e
# find_pano_id, (1.279925, 103.790964): e
# find_pano_id, (1.350638, 103.997099): e
# find_pano_id, (1.356434, 103.750897): e
# find_pano_id, (1.320067, 103.794301): e
# find_pano_id, (1.325069, 103.91221): e
# find_pano_id, (1.299352, 103.779558): e
# find_pano_id, (1.316611, 103.814786): e
# find_pano_id, (1.32477, 103.921932): e
# find_pano_id, (1.43867, 103.829074): e
# find_pano_id, (1.339147, 103.897378): e
# find_pano_id, (1.326295, 103.825264): e
# find_pano_id, (1.374595, 103.898146): e
# find_pano_id, (1.328519, 103.882931): e
# find_pano_id, (1.262675, 103.804794): e
# find_pano_id, (1.31087, 103.861381): e
# find_pano_id, (1.338913, 103.785825): e
# find_pano_id, (1.312314, 103.762965): e
# find_pano_id, (1.401219, 103.878866): e
# find_pano_id, (1.337536, 103.776893): e
# find_pano_id, (1.288084, 103.833706): e
# find_pano_id, (1.381883, 103.739564): e
# find_pano_id, (1.344554, 103.749013): e
# find_pano_id, (1.342471, 103.953879): e
# find_pano_id, (1.372106, 103.76551): e
# find_pano_id, (1.359845, 103.866012): e
# find_pano_id, (1.3766, 103.751505): e
# find_pano_id, (1.311806, 103.904634): e
# find_pano_id, (1.311184, 103.929148): e
# find_pano_id, (1.385438, 103.869037): e
# find_pano_id, (1.339478, 103.872275): e
# find_pano_id, (1.345989, 103.852631): e
# find_pano_id, (1.297846, 103.893582): e
# find_pano_id, (1.329466, 103.871503): e
# find_pano_id, (1.369256, 103.843552): e
# find_pano_id, (1.280503, 103.816821): e
# find_pano_id, (1.333436, 103.726713): e
# find_pano_id, (1.327911, 103.9668): e
# find_pano_id, (1.317878, 103.885669): e
# find_pano_id, (1.317167, 103.849899): e
# find_pano_id, (1.335203, 103.861371): e
# find_pano_id, (1.341909, 103.881846): e
# find_pano_id, (1.441515, 103.823723): e
# find_pano_id, (1.334642, 103.802475): e
# find_pano_id, (1.32095, 103.796619): e
# find_pano_id, (1.347246, 103.953755): e
# find_pano_id, (1.438008, 103.833014): e
# find_pano_id, (1.371729, 103.764362): e
# find_pano_id, (1.345748, 103.731143): e
# find_pano_id, (1.297136, 103.840049): e
# find_pano_id, (1.326404, 103.713564): e
# find_pano_id, (1.385685, 103.838859): e
# find_pano_id, (1.320782, 103.890209): e
# find_pano_id, (1.342625, 103.869041): e
# find_pano_id, (1.310452, 103.768576): e
# find_pano_id, (1.385284, 103.89631): e
# find_pano_id, (1.323373, 103.900073): e
# find_pano_id, (1.315937, 103.911655): e
# find_pano_id, (1.317917, 103.918229): e
# find_pano_id, (1.296795, 103.787518): e
# find_pano_id, (1.364755, 103.865291): e
# find_pano_id, (1.358916, 103.942165): e
# find_pano_id, (1.356031, 103.891058): e
# find_pano_id, (1.314972, 103.922034): e
# find_pano_id, (1.363797, 103.860876): e
# find_pano_id, (1.305999, 103.849317): e
# find_pano_id, (1.384021, 103.872237): e
# find_pano_id, (1.367394, 103.968348): e
# find_pano_id, (1.377723, 103.896125): e
# find_pano_id, (1.366546, 103.877901): e
# find_pano_id, (1.316452, 103.935777): e
# find_pano_id, (1.320073, 103.797049): e
# find_pano_id, (1.322452, 103.783105): e
# find_pano_id, (1.30328, 103.833298): e
# find_pano_id, (1.325753, 103.795778): e
# find_pano_id, (1.376546, 103.871637): e
# find_pano_id, (1.27883, 103.811369): e
# find_pano_id, (1.331438, 103.720214): e
# find_pano_id, (1.331951, 103.714392): e
# find_pano_id, (1.352939, 103.957889): e
# find_pano_id, (1.292897, 103.835638): e
# find_pano_id, (1.343471, 103.951915): e
# find_pano_id, (1.424599, 103.823582): e
# find_pano_id, (1.39514, 103.901937): e
# find_pano_id, (1.324989, 103.758683): e
# find_pano_id, (1.315367, 103.820361): e
# find_pano_id, (1.32298, 103.717231): e
# find_pano_id, (1.368203, 103.852552): e
# find_pano_id, (1.318599, 103.85472): e
# find_pano_id, (1.320215, 103.900624): e
# find_pano_id, (1.336027, 103.850368): e
# find_pano_id, (1.389801, 103.987506): e
# find_pano_id, (1.305927, 103.853356): e
# find_pano_id, (1.336547, 103.787682): e
# find_pano_id, (1.377979, 103.748341): e
# find_pano_id, (1.33862, 103.964354): e
# find_pano_id, (1.424929, 103.831998): e
# find_pano_id, (1.315586, 103.907285): e
# find_pano_id, (1.346227, 103.748525): e
# find_pano_id, (1.377343, 103.76212): e
# find_pano_id, (1.278301, 103.823332): e
# find_pano_id, (1.363904, 103.885493): e
# find_pano_id, (1.364378, 103.861838): e
# find_pano_id, (1.424912, 103.828759): e
# find_pano_id, (1.366076, 103.930996): e
# find_pano_id, (1.336586, 103.935579): e
# find_pano_id, (1.392913, 103.828125): e
# find_pano_id, (1.38868, 103.908602): e
# find_pano_id, (1.353759, 103.954617): e
# find_pano_id, (1.341142, 103.761123): e
# find_pano_id, (1.332825, 103.742205): e
# find_pano_id, (1.401068, 103.87215): e
# find_pano_id, (1.352263, 103.872684): e
# find_pano_id, (1.315692, 103.897932): e
# find_pano_id, (1.315412, 103.873216): e
# find_pano_id, (1.278426, 103.810708): e
# find_pano_id, (1.273793, 103.830348): e
# find_pano_id, (1.323732, 103.906567): e
# find_pano_id, (1.381275, 103.746411): e
# find_pano_id, (1.338936, 103.771095): e
# find_pano_id, (1.315932, 103.937595): e
# find_pano_id, (1.299102, 103.853098): e
# find_pano_id, (1.300462, 103.817056): e
# find_pano_id, (1.310512, 103.826002): e
# find_pano_id, (1.366608, 103.876055): e
# find_pano_id, (1.312345, 103.894641): e
# find_pano_id, (1.324661, 103.913874): e
# find_pano_id, (1.272323, 103.802204): e
# find_pano_id, (1.346522, 103.940643): e
# find_pano_id, (1.306457, 103.840419): e
# find_pano_id, (1.378142, 103.896111): e
# find_pano_id, (1.337863, 103.785223): e
# find_pano_id, (1.376648, 104.004311): e
# find_pano_id, (1.363839, 103.767686): e
# find_pano_id, (1.326375, 103.885787): e
# find_pano_id, (1.274175, 103.829898): e
# find_pano_id, (1.34885, 103.96578): e
# find_pano_id, (1.332692, 103.912071): e
# find_pano_id, (1.335141, 103.744622): e
# find_pano_id, (1.311098, 103.841425): e
# find_pano_id, (1.344299, 103.774165): e
# find_pano_id, (1.335301, 103.897033): e
# find_pano_id, (1.367441, 103.928214): e
# find_pano_id, (1.316438, 103.755129): e
# find_pano_id, (1.340752, 103.852894): e
# find_pano_id, (1.319503, 103.788983): e
# find_pano_id, (1.367741, 103.852667): e
# find_pano_id, (1.350126, 103.967562): e
# find_pano_id, (1.41984, 103.864252): e
# find_pano_id, (1.39219, 103.880581): e
# find_pano_id, (1.382755, 103.737157): e
# find_pano_id, (1.348028, 103.745019): e
# find_pano_id, (1.378402, 103.933192): e
# find_pano_id, (1.326899, 103.971771): e
# find_pano_id, (1.320642, 103.894357): e
# find_pano_id, (1.319196, 103.983419): e
# find_pano_id, (1.330511, 103.791981): e
# find_pano_id, (1.376504, 103.848652): e
# find_pano_id, (1.373265, 103.944277): e
# find_pano_id, (1.362317, 103.965962): e
# find_pano_id, (1.395025, 103.884818): e
# find_pano_id, (1.298076, 103.800558): e
# find_pano_id, (1.332466, 103.947837): e
# find_pano_id, (1.372925, 103.860626): e
# find_pano_id, (1.372059, 103.834597): e
# find_pano_id, (1.310388, 103.837468): e
# find_pano_id, (1.339242, 103.771823): e
# find_pano_id, (1.292015, 103.856064): e
# find_pano_id, (1.379745, 103.920524): e
# find_pano_id, (1.336726, 103.765539): e
# find_pano_id, (1.379536, 103.978623): e
# find_pano_id, (1.363132, 103.880316): e
# find_pano_id, (1.347384, 103.96193): e
# find_pano_id, (1.303883, 103.781739): e
# find_pano_id, (1.323423, 103.820317): e
# find_pano_id, (1.305514, 103.881297): e
# find_pano_id, (1.291464, 103.822975): e
# find_pano_id, (1.272601, 103.847511): e
# find_pano_id, (1.389918, 103.892548): e
# find_pano_id, (1.342511, 103.755931): e
# find_pano_id, (1.326163, 103.725533): e
# find_pano_id, (1.355127, 103.836969): e
# find_pano_id, (1.347822, 103.753335): e
# find_pano_id, (1.308502, 103.757153): e
# find_pano_id, (1.308834, 103.941137): e
# find_pano_id, (1.356798, 103.947242): e
# find_pano_id, (1.30856, 103.857795): e
# find_pano_id, (1.305399, 103.893034): e
# find_pano_id, (1.320819, 103.811931): e
# find_pano_id, (1.391264, 103.903119): e
# find_pano_id, (1.386312, 103.903668): e
# find_pano_id, (1.296486, 103.772256): e
# find_pano_id, (1.309321, 103.79145): e
# find_pano_id, (1.315005, 103.81275): e
# find_pano_id, (1.362367, 103.833564): e
# find_pano_id, (1.325648, 103.926027): e
# find_pano_id, (1.324523, 103.839054): e
# find_pano_id, (1.347032, 103.93786): e
# find_pano_id, (1.343727, 103.851969): e
# find_pano_id, (1.373971, 103.853141): e
# find_pano_id, (1.341237, 103.854778): e
# find_pano_id, (1.318622, 103.771344): e
# find_pano_id, (1.313117, 103.766468): e
# find_pano_id, (1.297672, 103.803991): e
# find_pano_id, (1.396864, 103.904363): e
# find_pano_id, (1.327809, 103.893691): e
# find_pano_id, (1.334518, 103.939511): e
# find_pano_id, (1.331092, 103.90759): e
# find_pano_id, (1.340156, 103.721218): e
# find_pano_id, (1.325889, 103.890381): e
# find_pano_id, (1.320067, 103.808809): e
# find_pano_id, (1.360187, 103.844729): e
# find_pano_id, (1.346895, 103.890679): e
# find_pano_id, (1.362681, 103.955931): e
# find_pano_id, (1.30638, 103.861793): e
# find_pano_id, (1.344934, 103.771626): e
# find_pano_id, (1.375617, 103.969135): e
# find_pano_id, (1.336873, 103.846135): e
# find_pano_id, (1.328817, 103.929719): e
# find_pano_id, (1.37059, 103.955418): e
# find_pano_id, (1.366505, 103.895541): e
# find_pano_id, (1.335819, 103.773034): e
# find_pano_id, (1.318189, 103.866862): e
# find_pano_id, (1.37893, 103.896897): e
# find_pano_id, (1.264882, 103.806119): e
# find_pano_id, (1.370621, 103.763692): e
# find_pano_id, (1.319237, 103.942813): e
# find_pano_id, (1.325574, 103.862396): e
# find_pano_id, (1.38801, 103.827799): e
# find_pano_id, (1.381542, 103.935212): e
# find_pano_id, (1.303871, 103.792912): e
# find_pano_id, (1.343876, 103.859837): e
# find_pano_id, (1.337112, 103.767338): e
# find_pano_id, (1.360423, 103.843115): e
# find_pano_id, (1.337417, 103.849748): e
# find_pano_id, (1.300282, 103.862837): e
# find_pano_id, (1.282221, 103.85965): e
# find_pano_id, (1.336819, 103.843419): e
# find_pano_id, (1.319229, 103.802882): e
# find_pano_id, (1.332302, 103.879434): e
# find_pano_id, (1.264959, 103.80458): e
# find_pano_id, (1.325962, 103.870934): e
# find_pano_id, (1.349959, 103.879794): e
# find_pano_id, (1.368406, 103.836282): e
# find_pano_id, (1.326424, 103.820407): e
# find_pano_id, (1.331671, 103.938489): e
# find_pano_id, (1.310373, 103.824157): e
# find_pano_id, (1.297017, 103.833479): e
# find_pano_id, (1.287564, 103.84275): e
# find_pano_id, (1.26426, 103.803093): e
# find_pano_id, (1.346708, 103.961721): e
# find_pano_id, (1.274615, 103.797243): e
# find_pano_id, (1.283931, 103.818669): e
# find_pano_id, (1.35084, 103.874579): e
# find_pano_id, (1.375511, 103.884698): e
# find_pano_id, (1.397574, 103.860224): e
# find_pano_id, (1.364752, 103.863771): e
# find_pano_id, (1.400711, 103.912951): e
# find_pano_id, (1.391344, 103.886414): e
# find_pano_id, (1.340304, 103.774025): e
# find_pano_id, (1.279991, 103.840705): e
# find_pano_id, (1.302135, 103.847251): e
# find_pano_id, (1.390177, 103.900025): e
# find_pano_id, (1.3195, 103.916088): e
# find_pano_id, (1.300265, 103.79862): e
# find_pano_id, (1.361094, 103.967045): e
# find_pano_id, (1.358487, 103.866902): e
# find_pano_id, (1.311552, 103.894393): e
# find_pano_id, (1.34441, 103.745835): e
# find_pano_id, (1.304409, 103.899946): e
# find_pano_id, (1.357924, 103.74906): e
# find_pano_id, (1.343026, 103.943894): e
# find_pano_id, (1.316305, 103.862121): e
# find_pano_id, (1.355512, 103.834734): e
# find_pano_id, (1.306058, 103.911885): e
# find_pano_id, (1.369084, 103.978505): e
# find_pano_id, (1.330044, 103.933936): e
# find_pano_id, (1.394532, 103.90433): e
# find_pano_id, (1.319142, 103.838304): e
# find_pano_id, (1.334534, 103.921864): e
# find_pano_id, (1.348052, 103.74937): e
# find_pano_id, (1.271682, 103.805996): e
# find_pano_id, (1.275918, 103.835864): e
# find_pano_id, (1.300384, 103.838817): e
# find_pano_id, (1.429887, 103.845721): e
# find_pano_id, (1.319279, 103.948258): e
# find_pano_id, (1.367022, 103.964093): e
# find_pano_id, (1.321614, 103.944034): e
# find_pano_id, (1.320545, 103.801367): e
# find_pano_id, (1.370613, 103.873771): e
# find_pano_id, (1.356567, 103.88132): e
# find_pano_id, (1.320661, 103.873268): e
# find_pano_id, (1.326022, 103.848784): e
# find_pano_id, (1.298283, 103.823741): e
# find_pano_id, (1.336839, 103.941456): e
# find_pano_id, (1.33156, 103.866185): e
# find_pano_id, (1.403897, 103.903447): e
# find_pano_id, (1.359949, 103.832946): e
# find_pano_id, (1.278596, 103.82494): e
# find_pano_id, (1.368909, 103.840758): e
# find_pano_id, (1.277607, 103.796143): e
# ...
# find_pano_id, (1.361781, 103.895989): e
# find_pano_id, (1.311407, 103.943381): e
# find_pano_id, (1.320024, 103.907704): e
# find_pano_id, (1.409446, 103.831122): e
# find_pano_id, (1.331918, 103.98922): e
# find_pano_id, (1.327235, 103.892027): e
# find_pano_id, (1.36112, 103.830649): e
# find_pano_id, (1.318035, 103.86341): e
# find_pano_id, (1.295428, 103.851284): e
# find_pano_id, (1.352999, 103.879877): e
# find_pano_id, (1.331722, 103.943211): e
# find_pano_id, (1.317189, 103.823279): e
# find_pano_id, (1.328702, 103.946844): e
# find_pano_id, (1.337687, 103.776975): e
# find_pano_id, (1.315989, 103.793459): e
# find_pano_id, (1.333702, 103.915579): e
# find_pano_id, (1.336025, 103.868492): e
# find_pano_id, (1.317551, 103.940896): e
# find_pano_id, (1.334876, 103.727486): e
# find_pano_id, (1.391066, 103.872154): e
# find_pano_id, (1.32216, 103.868286): e
# find_pano_id, (1.37579, 103.887357): e
# find_pano_id, (1.381192, 103.828033): e
# find_pano_id, (1.330407, 103.902573): e
# find_pano_id, (1.31392, 103.838067): e
# find_pano_id, (1.300516, 103.860471): e
# find_pano_id, (1.366117, 103.891248): e
# find_pano_id, (1.355071, 103.867292): e
# find_pano_id, (1.367833, 103.867925): e
# find_pano_id, (1.334794, 103.911388): e
# find_pano_id, (1.294867, 103.829336): e
# find_pano_id, (1.387785, 103.83021): e
# find_pano_id, (1.319863, 103.81249): e
# find_pano_id, (1.289881, 103.789532): e
# find_pano_id, (1.337373, 103.858529): e
# find_pano_id, (1.330205, 103.871685): e
# find_pano_id, (1.359212, 103.88171): e
# find_pano_id, (1.336225, 103.937685): e
# find_pano_id, (1.377776, 103.896665): e
# find_pano_id, (1.334548, 103.928881): e
# find_pano_id, (1.314373, 103.761782): e
# find_pano_id, (1.348826, 103.772537): e
# find_pano_id, (1.322505, 103.951372): e
# find_pano_id, (1.399384, 103.86695): e
# find_pano_id, (1.38277, 103.874909): e
# find_pano_id, (1.323863, 103.830126): e
# find_pano_id, (1.353425, 103.865637): e
# find_pano_id, (1.311588, 103.749564): e
# find_pano_id, (1.268439, 103.824346): e
# find_pano_id, (1.309556, 103.833198): e
# find_pano_id, (1.394438, 103.867617): e
# find_pano_id, (1.324536, 103.861592): e
# find_pano_id, (1.363849, 103.856119): e
# find_pano_id, (1.326329, 103.893253): e
# find_pano_id, (1.330637, 103.784306): e
# find_pano_id, (1.380163, 103.740261): e
# find_pano_id, (1.331861, 103.914415): e
# find_pano_id, (1.320285, 103.724766): e
# find_pano_id, (1.338154, 103.741124): e
# find_pano_id, (1.315597, 103.791565): e
# find_pano_id, (1.334343, 103.920669): e
# find_pano_id, (1.331103, 103.796868): e
# find_pano_id, (1.308323, 103.877572): e
# find_pano_id, (1.368939, 103.831268): e
# find_pano_id, (1.326397, 103.861099): e
# find_pano_id, (1.345313, 103.771773): e
# find_pano_id, (1.360171, 103.76208): e
# find_pano_id, (1.30471, 103.877708): e
# find_pano_id, (1.317786, 103.793568): e
# find_pano_id, (1.330589, 103.944754): e
# find_pano_id, (1.399909, 103.817535): e
# find_pano_id, (1.339494, 103.966477): e
# find_pano_id, (1.322338, 103.949254): e
# find_pano_id, (1.337978, 103.736448): e
# find_pano_id, (1.30579, 103.760958): e
# find_pano_id, (1.332717, 103.954768): e
# find_pano_id, (1.357488, 103.85425): e
# find_pano_id, (1.326614, 103.899685): e
# find_pano_id, (1.388752, 103.845905): e
# find_pano_id, (1.325545, 103.775052): e
# find_pano_id, (1.345532, 103.884874): e
# find_pano_id, (1.320879, 103.869784): e
# find_pano_id, (1.307719, 103.839442): e
# find_pano_id, (1.352718, 103.932458): e
# find_pano_id, (1.318072, 103.844088): e
# find_pano_id, (1.37611, 103.832285): e
# find_pano_id, (1.280068, 103.869121): e
# find_pano_id, (1.373441, 103.908643): e
# find_pano_id, (1.381353, 103.7618): e
# find_pano_id, (1.324411, 103.767714): e
# find_pano_id, (1.391158, 103.846061): e
# find_pano_id, (1.3966, 103.909708): e
# find_pano_id, (1.345315, 103.964183): e
# find_pano_id, (1.334924, 103.886001): e
# find_pano_id, (1.343482, 103.94122): e
# find_pano_id, (1.308138, 103.770558): e
# find_pano_id, (1.320261, 103.908229): e
# find_pano_id, (1.307752, 103.784637): e
# find_pano_id, (1.361116, 103.834687): e
# find_pano_id, (1.313444, 103.841668): e
# find_pano_id, (1.32187, 103.905428): e
# find_pano_id, (1.349575, 103.850175): e
# find_pano_id, (1.298112, 103.871758): e
# find_pano_id, (1.274229, 103.806746): e
# find_pano_id, (1.381097, 103.888819): e
# find_pano_id, (1.384687, 103.871787): e
# find_pano_id, (1.340832, 103.918507): e
# find_pano_id, (1.356207, 103.856469): e
# find_pano_id, (1.369614, 103.772473): e
# find_pano_id, (1.312511, 103.884833): e
# find_pano_id, (1.288085, 103.792209): e
# find_pano_id, (1.310203, 103.80607): e
# find_pano_id, (1.366964, 103.864401): e
# find_pano_id, (1.277368, 103.856564): e
# find_pano_id, (1.32233, 103.806523): e
# find_pano_id, (1.334796, 103.867088): e
# find_pano_id, (1.346205, 103.919654): e
# find_pano_id, (1.397048, 103.857351): e
# find_pano_id, (1.438792, 103.833881): e
# find_pano_id, (1.281872, 103.836459): e
# find_pano_id, (1.364954, 103.843154): e
# find_pano_id, (1.317242, 103.756852): e
# find_pano_id, (1.36027, 103.88901): e
# find_pano_id, (1.316728, 103.852582): e
# find_pano_id, (1.306852, 103.805423): e
# find_pano_id, (1.289117, 103.839997): e
# find_pano_id, (1.334123, 103.869322): e
# find_pano_id, (1.389619, 103.996455): e
# find_pano_id, (1.371404, 103.892279): e
# find_pano_id, (1.337298, 103.767979): e
# find_pano_id, (1.319662, 103.861612): e
# find_pano_id, (1.302906, 103.803854): e
# find_pano_id, (1.372338, 103.854143): e
# find_pano_id, (1.35323, 103.754068): e
# find_pano_id, (1.355542, 103.843755): e
# find_pano_id, (1.386439, 103.914): e
# find_pano_id, (1.346994, 103.856227): e
# find_pano_id, (1.348032, 103.844388): e
# find_pano_id, (1.313717, 103.79481): e
# find_pano_id, (1.309688, 103.768221): e
# find_pano_id, (1.336679, 103.937088): e
# find_pano_id, (1.310921, 103.843649): e
# find_pano_id, (1.311698, 103.872187): e
# find_pano_id, (1.288806, 103.825698): e
# find_pano_id, (1.344931, 103.927972): e
# find_pano_id, (1.347002, 103.743938): e
# find_pano_id, (1.387132, 103.866562): e
# find_pano_id, (1.344342, 103.780118): e
# find_pano_id, (1.343082, 103.916219): e
# find_pano_id, (1.32665, 103.901818): e
# find_pano_id, (1.367656, 103.77009): e
# find_pano_id, (1.315618, 103.900974): e
# find_pano_id, (1.380624, 103.745925): e
# find_pano_id, (1.358992, 103.832405): e
# find_pano_id, (1.324527, 103.868788): e
# find_pano_id, (1.312716, 103.879746): e
# find_pano_id, (1.342387, 103.945826): e
# find_pano_id, (1.389995, 103.890771): e
# find_pano_id, (1.327376, 103.884716): e
# find_pano_id, (1.378835, 103.831869): e
# find_pano_id, (1.311465, 103.772119): e
# find_pano_id, (1.340616, 103.946441): e
# find_pano_id, (1.318057, 103.788994): e
# find_pano_id, (1.360019, 103.844624): e
# find_pano_id, (1.361486, 103.86131): e
# find_pano_id, (1.361354, 103.833449): e
# find_pano_id, (1.304488, 103.887986): e
# find_pano_id, (1.435397, 103.831475): e
# find_pano_id, (1.351733, 103.986263): e
# find_pano_id, (1.369697, 103.867422): e
# find_pano_id, (1.371874, 103.828529): e
# find_pano_id, (1.276216, 103.859145): e
# find_pano_id, (1.326673, 103.812432): e
# find_pano_id, (1.306846, 103.908514): e
# find_pano_id, (1.313941, 103.859216): e
# find_pano_id, (1.31152, 103.827696): e
# find_pano_id, (1.302578, 103.811344): e
# find_pano_id, (1.357848, 103.878825): e
# find_pano_id, (1.326936, 103.891537): e
# find_pano_id, (1.31046, 103.825916): e
# find_pano_id, (1.314846, 103.765768): e
# find_pano_id, (1.308225, 103.760765): e
# find_pano_id, (1.350499, 103.833593): e
# find_pano_id, (1.398377, 103.871747): e
# find_pano_id, (1.378444, 103.878208): e
# find_pano_id, (1.365288, 103.8939): e
# find_pano_id, (1.328788, 103.818749): e
# find_pano_id, (1.334564, 103.921393): e
# find_pano_id, (1.289407, 103.793473): e
# find_pano_id, (1.322647, 103.857276): e
# find_pano_id, (1.400076, 103.897408): e
# find_pano_id, (1.298521, 103.780919): e
# find_pano_id, (1.354632, 103.870984): e
# find_pano_id, (1.317135, 103.859609): e
# find_pano_id, (1.313165, 103.839092): e
# find_pano_id, (1.370338, 103.89134): e
# find_pano_id, (1.326328, 103.768289): e
# find_pano_id, (1.411204, 103.830174): e
# find_pano_id, (1.395831, 103.87572): e
# find_pano_id, (1.323323, 103.882055): e
# find_pano_id, (1.385132, 103.893291): e
# find_pano_id, (1.386142, 103.821852): e
# find_pano_id, (1.328378, 103.937749): e
# find_pano_id, (1.313041, 103.849774): e
# find_pano_id, (1.328489, 103.916373): e
# find_pano_id, (1.296635, 103.851148): e
# find_pano_id, (1.332221, 103.989347): e
# find_pano_id, (1.325304, 103.792799): e
# find_pano_id, (1.336173, 103.968257): e
# find_pano_id, (1.329856, 103.934673): e
# find_pano_id, (1.384184, 103.895368): e
# find_pano_id, (1.397212, 103.908172): e
# find_pano_id, (1.32563, 103.725751): e
# find_pano_id, (1.271393, 103.827035): e
# find_pano_id, (1.332677, 103.766667): e
# find_pano_id, (1.354802, 103.887414): e
# find_pano_id, (1.339576, 103.721181): e
# find_pano_id, (1.331752, 103.87885): e
# find_pano_id, (1.389069, 103.861534): e
# find_pano_id, (1.397381, 103.888549): e
# find_pano_id, (1.315143, 103.750785): e
# find_pano_id, (1.396934, 103.908524): e
# find_pano_id, (1.320277, 103.740196): e
# find_pano_id, (1.304978, 103.788091): e
# find_pano_id, (1.398442, 103.885149): e
# find_pano_id, (1.321069, 103.873185): e
# find_pano_id, (1.328292, 103.890058): e
# find_pano_id, (1.320431, 103.758952): e
# find_pano_id, (1.311449, 103.942827): e
# find_pano_id, (1.413071, 103.83891): e
# find_pano_id, (1.322563, 103.918955): e
# find_pano_id, (1.326697, 103.902477): e
# find_pano_id, (1.365912, 103.956931): e
# find_pano_id, (1.349344, 103.969215): e
# find_pano_id, (1.324772, 103.872172): e
# find_pano_id, (1.308943, 103.86415): e
# find_pano_id, (1.340551, 103.770777): e
# find_pano_id, (1.289352, 103.831259): e
# find_pano_id, (1.324818, 103.839331): e
# find_pano_id, (1.34401, 103.747261): e
# find_pano_id, (1.353288, 103.861562): e
# find_pano_id, (1.302246, 103.801448): e
# find_pano_id, (1.298906, 103.780648): e
# find_pano_id, (1.439069, 103.826271): e
# find_pano_id, (1.312536, 103.924419): e
# find_pano_id, (1.337674, 103.891785): e
# find_pano_id, (1.338052, 103.980277): e
# find_pano_id, (1.368812, 103.748121): e
# find_pano_id, (1.377258, 103.88049): e
# find_pano_id, (1.331023, 103.927685): e
# find_pano_id, (1.352254, 103.848044): e
# find_pano_id, (1.337288, 103.923817): e
# find_pano_id, (1.331116, 103.944121): e
# find_pano_id, (1.318134, 103.932881): e
# find_pano_id, (1.281816, 103.832466): e
# find_pano_id, (1.317065, 103.89728): e
# find_pano_id, (1.389164, 103.752586): e
# find_pano_id, (1.350734, 103.932137): e
# find_pano_id, (1.327646, 103.762399): e
# find_pano_depth, (_g617awJTsgQ3jTD---7Ig): e
# find_pano_depth, (fYFbJaGChrWObIniK4iaEQ): e
# find_pano_depth, (HShX6RO1A6jvXv_pS2SSOw): e
# find_pano_depth, (PGXqyFM8J-_GHbDmyvp9-Q): e
# find_pano_depth, (9IGE6-fD2IcEKee7_P2mjQ): e
# find_pano_depth, (dVu9MBoXyg4lz_q-MSgeIg): e
# find_pano_depth, (PV4ySoncY8dDcayM87K33Q): e
# find_pano_depth, (DL_l211e3cz3nNjef3TEVw): e
# find_pano_depth, (CG1J2fGUhzG5JV8D5TFpGw): e
# find_pano_depth, (DJShla_8Ysgz4NvWMTFI6w): e
# find_pano_depth, (OTSuDZnWeQEpYBsTEK7mZA): e
# find_pano_depth, (2U0dvmICNY0PqxTs9Wk2yA): e
# find_pano_depth, (7_u1KD1vUCyUyZlf-3m3Lg): e
# find_pano_depth, (UAkUxp3NTTi_UyrWmjCycg): e
# find_pano_depth, (tJvSSYCTfeHxURdP0fug6w): e
# find_pano_depth, (1akZLGaAcJmWHW3jqCpJ8w): e
# find_pano_depth, (meIrbSDd1jgVxwTQaxXDag): e
# find_pano_depth, (OvtA782cHAQepbHmcGCFbQ): e
# find_pano_depth, (SIr6VbFpHIX9oCzsIBzuaQ): e
# find_pano_depth, (10sskWktjnOy0g9NTZYZfw): e
# find_pano_depth, (8JIYXXCOSbA1gxXnA-4XaQ): e
# find_pano_depth, (hDrsAoQIEBaYwJ61mRROoQ): e
# find_pano_depth, (ScWr4RtTZNaoYj8rSDXlgQ): e
# find_pano_depth, (s-x-5ggn5V0k4sxE6ZkO2Q): e
# find_pano_depth, (3owqrxtKqof-TQMku9z5kA): e
# find_pano_depth, (2mYB4x-pll7GPzoZM7H7JQ): e
# find_pano_depth, (_pvc_x2OSBSa6rKJRg46Sw): e
# find_pano_depth, (vUfsisODkq3LzQwYG5Qzxg): e
# find_pano_depth, (bWsDffTqztoNoySOYooU0A): e
# find_pano_depth, (fmmuKg81nyqP-6MVNhFTjw): e
# find_pano_depth, (kmHyGdCOX6oemLM6R5kIfA): e
# find_pano_depth, (xptbJP4QTC4DyoF0w0NwgA): e
# find_pano_depth, (EdVA-jYGw00MRExbH-7sug): e
# find_pano_depth, (b0diQk3CL0NvPERi8HEjLg): e
# find_pano_depth, (0GPhWevTAwaNKgwXOaS6Sg): e
# find_pano_depth, (gIA3I4QZc6BDcr3umpT_RA): e
# find_pano_depth, (BFr7dm-sQM93OfRXZ7XaOw): e
# find_pano_depth, (xZnabsImoN7_arQOF6viRQ): e
# find_pano_depth, (v0ce67qQzMue-4an8QE7iQ): e
# find_pano_depth, (8za6CSWoTxnKblpS36pzCw): e
# find_pano_depth, (ZuVRA7_fhfOPq2UPyLdVlQ): e
# find_pano_depth, (oEeEIEsW1DSL2IkpWGeCLA): e
# find_pano_depth, (3VcerbCPtOrMhgqGWoVAxQ): e
# find_pano_depth, (6c1mdrccD_6koEw_dNwVpQ): e
# find_pano_depth, (jUy-9Xsqc182QBUllbuzJg): e
# find_pano_depth, (Lzq8qaZ9hhy5y0R6BiJD6A): e
# find_pano_depth, (01wsWD7kyw3wwzlukg88mA): e
# find_pano_depth, (wP-PW_wk0oYx_efbdOjUYA): e
# find_pano_depth, (T2U9PoSHO3Ll62akdWIZ2g): e
# find_pano_depth, (VP_lG0Z-QqiSnZOI_xCw4A): e
# find_pano_depth, (9SGoLVZVnSd-5FMja2W7Mg): e
# find_pano_depth, (XMdgk0h0n9triNQ6k9RZUg): e
# find_pano_depth, (DPVdDx7J68zCYAimcWvE7A): e
# find_pano_depth, (FVhDXEJBmhH5Cx-8Pge8xw): e
# find_pano_depth, (UCJEouh9kMZ3tZs-iIpBGg): e
# find_pano_depth, (449kYG6Zk3F55Gt9iLC91w): e
# find_pano_depth, (F1_74S17I0aZ7uWRJ95A5w): e
# find_pano_depth, (cyeIFyez8GY445S96evYCA): e
# find_pano_depth, (Hi1-gUgK7d-7uY3Mm9MwUQ): e
# find_pano_depth, (3edztzy2-4bMaJJ5lRpJ4Q): e
# find_pano_depth, (wAwWO9mVcbHG_Majeyb_3w): e
# find_pano_depth, (XDkho4oNnPG9KdbcNeOyMQ): e
# find_pano_depth, (gKYdcZhZTuYz-vO_wb43tA): e
# find_pano_depth, (1-8ZMCZpBwUSSWxpXj1NOw): e
# find_pano_depth, (A-yVAL5rQ4FivzDtvq-H2A): e
# find_pano_depth, (RfOHmGzKrQoklyME68gX0g): e
# find_pano_depth, (EzRRm5H2oV7PnqWkAzMUbw): e
# find_pano_depth, (kyHzqah_pVLsBzm_Xe5fiA): e
# find_pano_depth, (6APHvz9f-qDX2N-piBikcQ): e
# find_pano_depth, (F87WuX9pySx8ZZCX1y5xhA): e
# find_pano_depth, (AD6ShEa6KSGBmgiP7i78xQ): e
# find_pano_depth, (3i6nO5TlATIUpWnk8JU3kQ): e
# find_pano_depth, (Jii-AISWyTUFAj1lGhvDtw): e
# find_pano_depth, (p0wFG35eLEnEp2lxc9eopA): e
# find_pano_depth, (fg5hFdHfhNX1pahS68myzA): e
# find_pano_depth, (u1Yjal5BZHyLohLdXEOpiA): e
# find_pano_depth, (yg7EiplTi0xF3jBQUW0sEg): e
# find_pano_depth, (jaxEEfT_lcr5jpY3zzXehw): e
# find_pano_depth, (am3bafll7eDJWyOpA8K-SQ): e
# find_pano_depth, (JdGzhOf5Dbu8p6xXaoLzPQ): e
# find_pano_depth, (p3TPKzUlEkYSOJGpt7ozeA): e
# find_pano_depth, (wxaHidTMDmWmDvonpH7Cow): e
# find_pano_depth, (sFHcJksHd1YEna1XkIMxQw): e
# find_pano_depth, (tF_LuhmZ7Rk1Hcqmk0MrTA): e
# find_pano_depth, (qsPpYdpcmDlN3UgqEFJtPA): e
# find_pano_depth, (Yr4S2khO8-AcrUTMW6zTPQ): e
# find_pano_depth, (5lwk2FaA8BVUovk_5TEO5w): e
# find_pano_depth, (Fbq0cVPvRWcDHEyScoP2vQ): e
# find_pano_depth, (mZLjRJzAOMS1FTJlEfK_xw): e
# find_pano_depth, (rfZpc7LJB_zBqLi2gt9vTQ): e
# find_pano_depth, (uUrc2kUR_AmFSeOEetYBbg): e
# find_pano_depth, (NhD6VWIo7dnaxGpdHPUw6w): e
# find_pano_depth, (IlgFTsP91z-_tjo-9LVcUA): e
# find_pano_depth, (2xY1mixsSa0j2QrvhXYakA): e
# find_pano_depth, (saDTIhsmsHCKMwYavcBCRg): e
# find_pano_depth, (vaR3airGh2YCRAPciJvJ8Q): e
# find_pano_depth, (_bBCP7Xyx_3cBIXkEOPNXQ): e
# find_pano_depth, (HETbX3LXQgx_-4YCL-ptbg): e
# find_pano_depth, (raS1cwitb7nYGdYR23oTgA): e
# find_pano_depth, (VX9mnlnm7LFmU6o1WHaHZg): e
# find_pano_depth, (N_uaUNxsl5AzHJTqvJSY5Q): e
# find_pano_depth, (htc0dsEdpmDXgJbACTuG3w): e
# find_pano_depth, (ixCrq2ZZoGnUVGsJ8tpB8g): e
# find_pano_depth, (WIDXgOufs6uY2ewg3ZuVZA): e
# find_pano_depth, (ngZgxUOWRN2MUwrvVGNA_w): e
# find_pano_depth, (rKQqYtq9RA4H1cZ9xcdUrw): e
# find_pano_depth, (VjYfP8dOmz-3PWE_XbbRfg): e
# find_pano_depth, (1S2gkA95Wvn0FGzY5uBvBw): e
# find_pano_depth, (aQc5niHGnrZGaHEWoFob2g): e
# find_pano_depth, (1P39neyiP-xd4MsvKKXKrg): e
# find_pano_depth, (QP8RYzZR6GGPjdkZbTyhrA): e
# find_pano_depth, (m0o1RvTD2dTK6NWY4vuelQ): e
# find_pano_depth, (GAuyVFVNk66bCP6LggM3zQ): e
# find_pano_depth, (RIYnqUSnkDwdv-8hx2AK0w): e
# find_pano_depth, (RfLFAWD3VzZRy4zUfE7f0A): e
# find_pano_depth, (jdQ1Bz1VAy7i8-enMfUzDQ): e
# find_pano_depth, (Q5ZGd4uWETvFQsgMlT78bg): e
# find_pano_depth, (hYNM8d8UIyUI2FMTYy51yg): e
# find_pano_depth, (qAFJyLd5xDDq1CGd7ywa_w): e
# find_pano_depth, (RF6r3zGNIOjtGF1hfOHd7Q): e
# find_pano_depth, (ppj97skjZJjJS8ri2HfnqA): e
# find_pano_depth, (hy4DazCSaxWkNF7SIqyXvg): e
# find_pano_depth, (GPlC2jTa67PMm2h-n5VG8Q): e
# find_pano_depth, (0j23e1LC_SRrpr4zeefx1Q): e
# find_pano_depth, (WUl7RGePV7kqEFjsgXwXvA): e
# find_pano_depth, (O4ZtTbPWzGu115stoduZKw): e
