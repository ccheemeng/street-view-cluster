# %% [markdown]
# If Dockerfiles have not been modified, connect to the Jupyter server with ```http://localhost:8001/tree?token=collect-street-view```
#
# This notebook describes a pipeline to download panoramas and their corresponding depth maps from Google Street View.
# It takes an input ```.csv``` describing a list of EPSG:4326 latitude/longitude pairs (as a list of length 2), each with an associated primary key, and attempts to save the panorama as a ```.jpg``` and a 3D cartesian point cloud derived from the depth map as a ```.csv``` in the target directory.
# A ```.csv``` indicating primary keys with found panoramas (which correspond to the filenames), and the true latitude, longitude, and elevation is also saved.

# %%
target_dir = "data"
input_latlons_fp = "shunfu-coordinates.csv"
pano_dir = "shunfu-panos"
point_cloud_dir = "shunfu-point-clouds"
log_filename = "shunfu-id.csv"

# %%
import aiocsv
import aiofiles
from aiohttp import ClientSession, ClientTimeout
from streetlevel import streetview

import asyncio
import csv
import json
import math
import pandas as pd
from pathlib import Path
import os

# %%
def depthmap_to_xyz(depthmap: list[list[float]],
                    xrange: tuple[float, float] = (-1.0, 1.0), yrange: tuple[float, float] = (-1.0, 1.0),
                    heading: float = 0,
                    rmin: float = 0.0, rmax: float = math.inf) -> list[list[float]]:
    pi = math.pi
    sin = math.sin
    cos = math.cos
    output = []
    width = len(depthmap[0])
    height = len(depthmap)
    x0 = xrange[0]
    dx = xrange[1] - x0
    y0 = yrange[0]
    dy = yrange[1] - y0
    h = -heading
    for i in range(height):
        for j in range(width):
            r = depthmap[i][j]
            if r < rmin or r > rmax:
                continue
            xnorm = ((j + 0.5) / width) * dx + x0
            ynorm = ((i + 0.5) / height) * dy + y0
            theta = -pi * xnorm
            phi = -pi / 2 * ynorm
            cartesian = [[-r * sin(h + theta) * cos(phi)],
                         [r * cos(h + theta) * cos(phi)],
                         [r * sin(phi)]]
            output.append([cartesian[0][0], cartesian[1][0], cartesian[2][0]])
    return output

async def find_pano_id(session, lat, lon, radius=50):
    try:
        return await streetview.find_panorama_async(lat, lon, session, radius=radius)
    except Exception as e:
        print(f"find_pano_id, ({lat}, {lon}): {e}")
        return None

async def find_pano_depth(session, panoid):
    try:
        return await streetview.find_panorama_by_id_async(panoid, session, download_depth=True)
    except Exception as e:
        print(f"find_pano_depth, {panoid}: {e}")
        return None
    
async def find_pano_full(session, lat, lon, radius=50):
    base_pano = await find_pano_id(session, lat, lon, radius)
    if base_pano:
        return await find_pano_depth(session, base_pano.id)
    else:
        return None

async def save_pano_point_cloud(target_dir, pano_dir, point_cloud_dir, id, lat, lon, session, csv_writer):
    pano = await find_pano_full(session, lat, lon)
    if pano and pano.depth and pano.heading and pano.elevation:
        try:
            image = await streetview.get_panorama_async(pano, session, zoom=0)
            point_cloud = depthmap_to_xyz(pano.depth.data[:,::-1], heading=pano.heading, rmin=1.1, rmax=60)
            with open(os.path.join(target_dir, pano_dir, f"{id}.jpg"), 'w') as fp:
                image.save(fp)
            with open(os.path.join(target_dir, point_cloud_dir, f"{id}.csv"), 'w') as fp:
                point_cloud_writer = csv.writer(fp)
                point_cloud_writer.writerows(point_cloud)
            await csv_writer.writerow([id, pano.lat, pano.lon, pano.elevation])
        except Exception as e:
            print(f"save_pano_point_cloud, {pano.id}: {e}")

async def main(target_dir, pano_dir, point_cloud_dir, ids, lats, lons, log_filename):
    Path(os.path.join(target_dir, pano_dir)).mkdir(parents=True, exist_ok=True)
    Path(os.path.join(target_dir, point_cloud_dir)).mkdir(parents=True, exist_ok=True)
    async with ClientSession(timeout=ClientTimeout(total=None), raise_for_status=True, trust_env=True) as session:
        async with aiofiles.open(os.path.join(target_dir, log_filename), 'w+') as fp:
            csv_writer = aiocsv.AsyncWriter(fp)
            await csv_writer.writerow(["id", "lat", "lon", "elevation"])
            tasks = []
            for i in range(len(ids)):
                tasks.append(save_pano_point_cloud(target_dir, pano_dir, point_cloud_dir, ids[i], lats[i], lons[i], session, csv_writer))
            await asyncio.gather(*tasks)

# %%
df = pd.read_csv(os.path.join(target_dir, input_latlons_fp))
df.columns = ["id", "lat", "lon"]
df = df.drop_duplicates(subset=["id"])
ids = df["id"].to_list()
lats = df["lat"].to_list()
lons = df["lon"].to_list()

await main(target_dir, pano_dir, point_cloud_dir, ids, lats, lons, log_filename)
# Out:
# find_pano_depth, vJmzqRVKJZ4stQHZ5Fb7OQ: Server disconnected
# find_pano_depth, 7Ji36yajtdBj6ppSSxy2eA: Server disconnected
# find_pano_depth, pBDqiazSlv3qH5iBm40a6w: Server disconnected
# find_pano_depth, NY5gqIJVDGDdncze8QRUmg: Server disconnected
# find_pano_depth, OblbY2DkqdHMT1Zx3gSEvw: Server disconnected
# find_pano_depth, c5YO2Pg0gv8larBFWgnJVg: Server disconnected
# save_pano_point_cloud, l8maHM_Nzu_ZmGZChywzqg: Server disconnected
# save_pano_point_cloud, POxGcpYS3ve6pq_T2uhoRA: Server disconnected
# save_pano_point_cloud, T39Mp0rlgwKZ9CxfefG0Eg: Server disconnected
# find_pano_depth, JvlgoEtlUHdh8ePQ-nZ99g: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_depth, xtTQvAiJuM8r9G3INAbyMA: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_depth, ZfhJ4vmHaHIdy-wwv3wsuw: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_depth, vAuEd6HKVdPbZSp3qtdMLg: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_depth, pRCiy4HOjnKbd6m7gEGg_Q: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_depth, HcOM3mGDb8dL7v-YEQsqnQ: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_depth, UmxS07I_vJI4y39C7NIfeg: Server disconnected
# find_pano_depth, YBBA3mKokWX-87hg3NvQEQ: Server disconnected
# find_pano_depth, CmWBWNa1CvW2Ghhpn0RDzQ: Server disconnected
# find_pano_depth, gHp4P3vi7xGuur_nCgbE5A: Cannot connect to host www.google.com:443 ssl:default [None]
# save_pano_point_cloud, AX-DiXwvA9lZ8onCOkMu4w: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# find_pano_depth, Q1VIPdt6xTj15RoMVlYeug: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_depth, 9zIfCFjhOxyQddJllfz5oA: Cannot connect to host www.google.com:443 ssl:default [None]
# save_pano_point_cloud, FOlX8N1srPl1gWyADNzLow: Server disconnected
# save_pano_point_cloud, ILxvYs6t-xxb1aAVEtNRJQ: Server disconnected
# save_pano_point_cloud, CBPNRb7nrBinD3OuqIoOqA: Server disconnected
# save_pano_point_cloud, 6nk0YqejN0aN1_pmMI4lyg: Server disconnected
# save_pano_point_cloud, th5F4io51QQKE7XFDgngLA: Server disconnected
# find_pano_depth, JYJZOQzro0B7MxiNWOUdlw: Server disconnected
# find_pano_depth, KCV2F1Sf3esibVpS9LpS2g: Server disconnected
# find_pano_id, (1.3536864548795, 103.837861281626): Cannot connect to host maps.googleapis.com:443 ssl:default [None]
# save_pano_point_cloud, f9cDZhUiUe-rWb28KmdUbA: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, JY6IRnvU9BvuPbHF62_Siw: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, oL3ZvacUx1YtBy-V6lG4eg: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, Y3JppNuzGh8tCc_Dz0n5ew: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, pNoU9M22Px93E6P0761Wbw: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, HqkJey2qqkUCed8Otmlu7w: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, jZ86PY-NPXBixySMPLUuoQ: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# find_pano_depth, dBWfsyXnW2pFIphfdcXHFQ: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_depth, GeDv9DgT7U20XbacwfQKDQ: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_depth, cuWUJ0YfOlzEwhPRQpifHw: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_depth, XpOkC5bJY49356TZ07Nr6A: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_depth, WmOnc21LPnoVZbW0S-r6Rg: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_depth, KTL5m1Nof884ktOQyCKmfw: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_depth, GBWgn-Re195Lfh2GiN4Ubg: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_depth, bRuOJ6jzxOJk3an0VPQi_g: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_depth, fdUQZt5j0pbmkQ4dzIopiQ: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_depth, 7U3zhS46DHw8v5HE1R6jtg: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_id, (1.34968974266542, 103.837896486957): Cannot connect to host maps.googleapis.com:443 ssl:default [None]
# find_pano_id, (1.34860074401037, 103.837872957765): Cannot connect to host maps.googleapis.com:443 ssl:default [None]
# find_pano_id, (1.35615631842857, 103.837902236573): Cannot connect to host maps.googleapis.com:443 ssl:default [None]
# find_pano_id, (1.34978255770877, 103.837848809387): Cannot connect to host maps.googleapis.com:443 ssl:default [None]
# find_pano_id, (1.35076939486758, 103.837884191627): Cannot connect to host maps.googleapis.com:443 ssl:default [None]
# save_pano_point_cloud, 3xbMLqffNxgE9USFy5iDSQ: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# find_pano_depth, -OzpQuCrfsWZ8FoXjYOPQg: Server disconnected
# save_pano_point_cloud, fsCQs2wKccM6LpjWjHjObQ: Server disconnected
# save_pano_point_cloud, ejneHNVAvbhEokq4pmaM4w: Server disconnected
# save_pano_point_cloud, yOnYPCQ9fVP16YfXPzZuXg: Server disconnected
# save_pano_point_cloud, iKp2sbTYNDdhlAYD6vD1_g: Server disconnected
# find_pano_depth, pa7p9xgeZF6fl-xPDi8b2A: Server disconnected
# find_pano_depth, MXOFGEYMujAkjciPHWZnQQ: Server disconnected
# find_pano_depth, Ts9GcSbDOxG6rHaFP35eQA: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_depth, vfaak4vS4C_0nPCFTJljAQ: Server disconnected
# save_pano_point_cloud, 4fLmx7IXHwLbMd6pRLd4aA: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, BpTcCDZrMKMXj4Gzlr7ZpQ: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, I0mR_hcARWhhW_SK2d7_6w: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, y4GFtd42_srw0Py39TojwA: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, XKbd2pgHqwCSPI8JpmoVjQ: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, bojAvb82r2kfZPAcKpe3cA: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# find_pano_id, (1.35305981190693, 103.838769015983): Cannot connect to host maps.googleapis.com:443 ssl:default [None]
# find_pano_id, (1.35148273466561, 103.838800771758): Cannot connect to host maps.googleapis.com:443 ssl:default [None]
# find_pano_id, (1.35066752000525, 103.838802275513): Cannot connect to host maps.googleapis.com:443 ssl:default [None]
# find_pano_depth, FE_pZmy5XPlfuN-DSmgwZQ: Server disconnected
# find_pano_depth, QfMMdyl20WgNyHNNGmMr9w: Server disconnected
# find_pano_depth, 3PZBlQZ-EtaqmERTDwZe-g: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_id, (1.34914980633781, 103.839662426414): Cannot connect to host maps.googleapis.com:443 ssl:default [None]
# find_pano_id, (1.34906038703162, 103.839655172959): Cannot connect to host maps.googleapis.com:443 ssl:default [None]
# find_pano_id, (1.34984076061249, 103.839477551892): Cannot connect to host maps.googleapis.com:443 ssl:default [None]
# find_pano_depth, 3ZYQSYJUFNMPflzw2Pradg: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_id, (1.35126414593845, 103.8399890092): Cannot connect to host maps.googleapis.com:443 ssl:default [None]
# find_pano_id, (1.35071186492169, 103.840082419805): Cannot connect to host maps.googleapis.com:443 ssl:default [None]
# find_pano_id, (1.35094010136675, 103.840076758555): Cannot connect to host maps.googleapis.com:443 ssl:default [None]
# save_pano_point_cloud, 2bAJNFAyOWKBdpNU23Vwtg: Server disconnected
# save_pano_point_cloud, Z9zwzzEeosff8pBB2e0v4w: Server disconnected
# save_pano_point_cloud, YSa3yabwOC38-Q0MJzY57w: Server disconnected
# find_pano_depth, MSbyYQnn2yl3Kl6k1iJrgw: Server disconnected
# find_pano_depth, eqhcNZ91dzNtXm5jpfMK_g: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_depth, wGHKzOPvyRSiIaBYFEUFkw: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_depth, hX2f66vIWraWiS6Y3p5w7A: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_id, (1.35262962554834, 103.84035619463): Cannot connect to host maps.googleapis.com:443 ssl:default [None]
# find_pano_id, (1.35228698622479, 103.840232973776): Cannot connect to host maps.googleapis.com:443 ssl:default [None]
# find_pano_depth, 7Qxv7hxn7UbX3ekDIrPesw: Cannot connect to host www.google.com:443 ssl:default [None]
# save_pano_point_cloud, EQcffS8Ssp7Ds575zKXf5g: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, T3JzEJ7tQTtBjkJ7iC48MA: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, pkChrPu55bNR_nNIjePcHA: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, o3ybl66Zf0pGeZSQZmZMRQ: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, M10g2tsFNIGpQGsubUSDug: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, YrSs3cIEG-sEw3chOtuwEw: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# find_pano_depth, ryIPeK4lNB37DGFv5C4N_w: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_depth, PBocB0ooMVg8uq0IqXzSqA: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_depth, bRiaksKVtm0EQO7zzsLHPA: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_depth, AFNsmWU_CZD29JyCDFE-0A: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_depth, m_229p1_MyZv_HtM2Hs2hQ: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_id, (1.35446706603354, 103.84122228205): Server disconnected
