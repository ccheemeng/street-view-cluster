# %% [markdown]
# If Dockerfiles have not been modified, connect to the Jupyter server with ```http://localhost:8001/tree?token=collect-street-view```
#
# This notebook describes a pipeline to download panoramas and their corresponding depth maps from Google Street View.
# It takes an input ```.csv``` describing a list of EPSG:4326 latitude/longitude pairs (as a list of length 2), each with an associated primary key, and attempts to save the panorama as a ```.jpg``` and a 3D cartesian point cloud derived from the depth map as a ```.csv``` in the target directory.
# A ```.csv``` indicating primary keys with found panoramas (which correspond to the filenames), and the true latitude, longitude, elevation, and heading is also saved.

# %%
target_dir = "data"
input_latlons_fp = "shunfu-locations.csv"
pano_dir = "shunfu-panos"
point_cloud_dir = "shunfu-point-clouds-google"
log_filename = "shunfu-id.csv"
align_panoramas_to_north = True
zoom = 1

# %%
import aiocsv
import aiofiles
from aiohttp import ClientSession, ClientTimeout
from PIL import Image
from streetlevel import streetview

import asyncio
import csv
import json
import math
import pandas as pd
from pathlib import Path
import os

# %%
def depthmap_to_xyz(depthmap: list[list[float]],
                    xrange: tuple[float, float] = (-1.0, 1.0), yrange: tuple[float, float] = (-1.0, 1.0),
                    heading: float = 0.0,
                    rmin: float = 0.0, rmax: float = math.inf) -> list[list[float]]:
    pi = math.pi
    sin = math.sin
    cos = math.cos
    output = []
    width = len(depthmap[0])
    height = len(depthmap)
    x0 = xrange[0]
    dx = xrange[1] - x0
    y0 = yrange[0]
    dy = yrange[1] - y0
    h = -heading
    for i in range(height):
        for j in range(width):
            r = depthmap[i][j]
            if r < rmin or r > rmax:
                continue
            xnorm = ((j + 0.5) / width) * dx + x0
            ynorm = ((i + 0.5) / height) * dy + y0
            theta = -pi * xnorm
            phi = -pi / 2 * ynorm
            cartesian = [[-r * sin(h + theta) * cos(phi)],
                         [r * cos(h + theta) * cos(phi)],
                         [r * sin(phi)]]
            output.append([cartesian[0][0], cartesian[1][0], cartesian[2][0]])
    return output

def align_image(image: Image, heading: float = 0.0) -> Image:
    pi = math.pi
    input_image = image
    width, height = image.size
    crop_width = int(round(heading % (2 * pi) / (2 * pi) * width))
    image_right = input_image.crop((width - crop_width, 0, width, height)) # not effect-free, crops input_image too
    output_image = Image.new("RGB", (width, height))
    output_image.paste(image_right)
    output_image.paste(input_image, (crop_width, 0))
    return output_image

async def find_pano_id(session, lat, lon, radius=50):
    try:
        return await streetview.find_panorama_async(lat, lon, session, radius=radius)
    except Exception as e:
        print(f"find_pano_id, ({lat}, {lon}): {e}")
        return None

async def find_pano_depth(session, panoid):
    try:
        return await streetview.find_panorama_by_id_async(panoid, session, download_depth=True)
    except Exception as e:
        print(f"find_pano_depth, {panoid}: {e}")
        return None
    
async def find_pano_full(session, lat, lon, radius=50):
    base_pano = await find_pano_id(session, lat, lon, radius)
    if base_pano:
        return await find_pano_depth(session, base_pano.id)
    else:
        return None

async def save_pano_point_cloud(target_dir, pano_dir, point_cloud_dir, id, lat, lon, session, csv_writer, zoom=0):
    pano = await find_pano_full(session, lat, lon)
    if pano and pano.depth and pano.heading and pano.elevation:
        try:
            image = await streetview.get_panorama_async(pano, session, zoom=zoom)
            heading = pano.heading
            if align_panoramas_to_north:
                image = align_image(image, heading=pano.heading)
                heading = 0.0
            point_cloud = depthmap_to_xyz(pano.depth.data[:,::-1], heading=pano.heading, rmin=1.1, rmax=60)
            with open(os.path.join(target_dir, pano_dir, f"{id}.jpg"), 'w') as fp:
                image.save(fp)
            with open(os.path.join(target_dir, point_cloud_dir, f"{id}.csv"), 'w') as fp:
                point_cloud_writer = csv.writer(fp)
                point_cloud_writer.writerows(point_cloud)
            await csv_writer.writerow([id, pano.lat, pano.lon, pano.elevation, heading])
        except Exception as e:
            print(f"save_pano_point_cloud, {pano.id}: {e}")

async def main(target_dir, pano_dir, point_cloud_dir, ids, lats, lons, log_filename, zoom=0):
    Path(os.path.join(target_dir, pano_dir)).mkdir(parents=True, exist_ok=True)
    Path(os.path.join(target_dir, point_cloud_dir)).mkdir(parents=True, exist_ok=True)
    async with ClientSession(timeout=ClientTimeout(total=None), raise_for_status=True, trust_env=True) as session:
        async with aiofiles.open(os.path.join(target_dir, log_filename), 'w+') as fp:
            csv_writer = aiocsv.AsyncWriter(fp)
            await csv_writer.writerow(["id", "lat", "lon", "elevation", "heading"])
            tasks = []
            for i in range(len(ids)):
                tasks.append(save_pano_point_cloud(target_dir, pano_dir, point_cloud_dir, ids[i], lats[i], lons[i], session, csv_writer, zoom))
            await asyncio.gather(*tasks)

# %%
df = pd.read_csv(os.path.join(target_dir, input_latlons_fp))
df.columns = ["id", "lat", "lon"]
df = df.drop_duplicates(subset=["id"])
ids = df["id"].to_list()
lats = df["lat"].to_list()
lons = df["lon"].to_list()

await main(target_dir, pano_dir, point_cloud_dir, ids, lats, lons, log_filename, zoom)
# Out:
# find_pano_depth, _4ISxn0v3TITxWYkgsSyew: Server disconnected
# find_pano_depth, r7-1ETUeA63tokG8cXl3Ew: Server disconnected
# find_pano_depth, Sv828Y5-PK9is5mZ375T-w: Server disconnected
# find_pano_depth, c79CUDdMJVDr4SytlR1WzQ: Server disconnected
# find_pano_depth, sM1RG-ZAUR82I6yByxblzg: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_depth, FeZo38wNjySwFxWbFfmROA: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_depth, 1A7GVCreCl70Z6M_MuZHKQ: Cannot connect to host www.google.com:443 ssl:default [None]
# save_pano_point_cloud, vg7mTPBK2ib4sb-tMzOQHw: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# find_pano_depth, oL3ZvacUx1YtBy-V6lG4eg: Server disconnected
# find_pano_depth, aZIkhrOkXtyCAdEDftcccw: Server disconnected
# save_pano_point_cloud, VRLDcKtlzLhw6adAG4TRqQ: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# find_pano_depth, nCAyA8WLLE0Ny4Aw0DiAog: Cannot connect to host www.google.com:443 ssl:default [None]
# save_pano_point_cloud, vjYiJ9mOjsut-UZ5i4PJpw: Server disconnected
# save_pano_point_cloud, T39Mp0rlgwKZ9CxfefG0Eg: Server disconnected
# save_pano_point_cloud, PiPjINXCxBqgL8Mtn7rV5g: Server disconnected
# save_pano_point_cloud, 3gcjRlgZ-D3en6L7qHqpeA: Server disconnected
# save_pano_point_cloud, NY5gqIJVDGDdncze8QRUmg: Server disconnected
# save_pano_point_cloud, PvMCx-i34OCyEnDIkhkyqg: Server disconnected
# save_pano_point_cloud, mLxzCXrRfj2Ujr7tDHQR7Q: Server disconnected
# save_pano_point_cloud, yjTwAMKWblzbrRkir9im7g: Server disconnected
# save_pano_point_cloud, pUcC7JKBIsswvlRLISWQkg: Server disconnected
# save_pano_point_cloud, EOrIwrIm4l0GBs99orM7mQ: Server disconnected
# save_pano_point_cloud, O74KFrHkyPMbWpDQPKpHbA: Server disconnected
# find_pano_depth, qBQVsqp5jT2VYv123KqXaA: Server disconnected
# find_pano_depth, a9rH6pMPq85Ymfm0ZBkMdQ: Server disconnected
# find_pano_depth, tEMgInPaI089kkfFr__BnQ: Server disconnected
# find_pano_depth, hpiRPRvS1PHGGu2hCdDmhQ: Server disconnected
# find_pano_depth, mtLefG6MiT5jHxchJS_cVQ: Server disconnected
# find_pano_depth, JYJZOQzro0B7MxiNWOUdlw: Server disconnected
# find_pano_depth, Pf396-M99b7TfTAd-qJ49w: Server disconnected
# save_pano_point_cloud, OblbY2DkqdHMT1Zx3gSEvw: Server disconnected
# find_pano_id, (1.35354504371888, 103.838490998471): Cannot connect to host maps.googleapis.com:443 ssl:default [None]
# find_pano_depth, 7U3zhS46DHw8v5HE1R6jtg: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_depth, Yxw9BpgrELZp7VgGLZuyHA: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_id, (1.3507188624339, 103.838335050622): Cannot connect to host maps.googleapis.com:443 ssl:default [None]
# find_pano_id, (1.35035318895417, 103.838338235035): Cannot connect to host maps.googleapis.com:443 ssl:default [None]
# save_pano_point_cloud, Jfn-_ltTcw3YsM5ZGJyE2Q: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# find_pano_id, (1.35071167493644, 103.838427487074): Cannot connect to host maps.googleapis.com:443 ssl:default [None]
# save_pano_point_cloud, 17FwWXuTFnhDDRZ8BdMqUA: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# find_pano_depth, um7_WC6WAmd-NsL_nH5nMw: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_depth, E5xnAk5pfsuf74Iydv857Q: Server disconnected
# find_pano_depth, VhuEz1alzG6Jg5TlbRD0BA: Server disconnected
# find_pano_depth, N0sbU0Leu3AaZSMRHtb9wg: Server disconnected
# save_pano_point_cloud, yWQFNTw-pg9ODI45EafvZg: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# find_pano_depth, 0pccDINnjva2eYhRxXq7Gw: Server disconnected
# find_pano_depth, 1et4Iik1Riz-OPQEKSJAnw: Server disconnected
# find_pano_depth, JKaknbMBwc0LEO6bJApXSQ: Server disconnected
# find_pano_depth, DDKCx6gemcetoEfHG0pZXg: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_depth, nUWhyD8JzWLCdVREawB1cA: Cannot connect to host www.google.com:443 ssl:default [None]
# save_pano_point_cloud, e7JAluk8uRKxJxzkZXXUtA: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, 6r85DPyri5tyBPyGlL0hQQ: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, -MK6WXkbSXUHOLCKidO78g: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, ktotT-ZiS4QBuswz5o4U_A: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, JdB3OZHyeHaUg7q5-mU5Nw: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, a6Ot1yUu56BCqq_CwrAvGA: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, OkCQTqEyvkjQSFkV8rSCNw: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, q2TC55Kb5BypgUArkGMU-Q: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, lXfXlBEasN_lfquVnJXs_w: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# find_pano_depth, EzI5_TTnvwYmsWszD4HY0w: Server disconnected
# find_pano_id, (1.35012038053293, 103.837554517968): Server disconnected
# find_pano_depth, sp5JVIRrelMzXbY-oaooLA: Server disconnected
# find_pano_depth, eSGw-KzjFTJultCdMW58vQ: Server disconnected
# find_pano_depth, o3ybl66Zf0pGeZSQZmZMRQ: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_depth, KblFQeD4-1C0S1tH5SX0MA: Server disconnected
# find_pano_depth, md2BzQpRyOHsN8N38VSJVw: Server disconnected
# find_pano_id, (1.35323603103791, 103.83816716142): Server disconnected
# find_pano_depth, -7St4yMYplQ-r3u9yPA1PA: Server disconnected
# find_pano_depth, ip--DYKZyOHjwg-7ep5ChQ: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_id, (1.35482888927771, 103.840669952758): Cannot connect to host maps.googleapis.com:443 ssl:default [None]
# find_pano_id, (1.35492725897384, 103.840714358393): Cannot connect to host maps.googleapis.com:443 ssl:default [None]
# find_pano_id, (1.35300106055118, 103.840582733764): Cannot connect to host maps.googleapis.com:443 ssl:default [None]
# find_pano_id, (1.35309025335092, 103.840618028259): Cannot connect to host maps.googleapis.com:443 ssl:default [None]
# find_pano_id, (1.35322748323912, 103.840583618338): Cannot connect to host maps.googleapis.com:443 ssl:default [None]
# find_pano_id, (1.35356365969848, 103.840724796373): Cannot connect to host maps.googleapis.com:443 ssl:default [None]
# find_pano_id, (1.35468943878274, 103.840114441259): Server disconnected
# find_pano_id, (1.34997716597803, 103.838646681131): Server disconnected
# find_pano_id, (1.35339107736051, 103.838070213903): Server disconnected
# find_pano_id, (1.35396185539313, 103.83823438784): Server disconnected
# find_pano_id, (1.34962355809393, 103.838654553725): Server disconnected
# find_pano_id, (1.3488669473665, 103.837767961005): Server disconnected
# find_pano_id, (1.35387018643975, 103.839324787345): Server disconnected
# find_pano_depth, hAoVy40nZcF95jjzWHVEHg: Server disconnected
# find_pano_depth, VfjOckND0YOwZbK2qPdPAQ: Server disconnected
# find_pano_depth, _7XnvFSIc_jQJFjqnYMUZA: Server disconnected
# find_pano_depth, 4_lbNV8p7twj2YGjZFISyg: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_depth, ztQqeiTTG9BBEYdEZ6-_Lg: Cannot connect to host www.google.com:443 ssl:default [None]
# save_pano_point_cloud, cDxVRHys9REIz7-_-3FEUQ: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, RKWxcu4gw1lKZozhh6nlgg: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, UAy3R2f63VCKCDNy8Iotqg: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, 1rXIzmKgj4Kb__gaTjpWKw: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, OjMUa7G8LpusYvMdXsFhmQ: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, Ygg20kzVsjZyt4ST7CM7lg: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# find_pano_depth, Y3JppNuzGh8tCc_Dz0n5ew: Server disconnected
# find_pano_depth, bnl7nQwAr9ZZ7qWFkZ3hNg: Server disconnected
# find_pano_depth, UsvvuDMULl5fzCfKBSlwgQ: Server disconnected
# find_pano_id, (1.35381401176526, 103.840829618506): Server disconnected
# find_pano_id, (1.35046094111462, 103.839943453861): Server disconnected
# find_pano_id, (1.35005062103128, 103.839741772159): Server disconnected
# find_pano_id, (1.35195263886112, 103.840246242348): Server disconnected
# find_pano_id, (1.35448038110121, 103.840004046888): Server disconnected
# find_pano_id, (1.35314336539935, 103.840548766138): Server disconnected
# find_pano_id, (1.3513544881881, 103.839542656001): Server disconnected
# find_pano_id, (1.35107919883392, 103.839978128991): Server disconnected
# find_pano_id, (1.35001404724895, 103.839512846099): Server disconnected
# find_pano_id, (1.35154782210509, 103.840104445611): Server disconnected
# find_pano_id, (1.35297312764678, 103.840479061767): Server disconnected
# find_pano_id, (1.35167456777944, 103.840039606603): Server disconnected
# find_pano_id, (1.3520351976292, 103.84027826384): Server disconnected
# find_pano_id, (1.35203051134819, 103.840149381804): Server disconnected
# find_pano_id, (1.34966314264613, 103.838179545231): Server disconnected
# find_pano_id, (1.35099063985249, 103.839969814036): Server disconnected
# find_pano_depth, sIzR5qLZcpXPGRoRzY70TA: Server disconnected
# find_pano_id, (1.35500852887468, 103.840293213103): Server disconnected
# find_pano_id, (1.34998128576723, 103.838096839081): Server disconnected
# find_pano_depth, dBzc9KeMYpxBE0Pb7liuGA: Server disconnected
# find_pano_id, (1.35461444910029, 103.840071362675): Server disconnected
# find_pano_depth, vFk8moUBArK1699pZHWRHg: Server disconnected
# find_pano_id, (1.35326872228482, 103.840698966797): Server disconnected
# save_pano_point_cloud, A4281Z1bhCCd0il6cGaOig: Server disconnected
# find_pano_id, (1.35013999364535, 103.839560258884): Server disconnected
# find_pano_id, (1.3523502790733, 103.838153539228): Server disconnected
# find_pano_depth, kQUB0WNAw9e5Io7npZRFuQ: Server disconnected
# find_pano_id, (1.3542685711846, 103.838916737896): Server disconnected
# find_pano_depth, g7iQZ2CT93h6FxtpyEeQIw: Server disconnected
# find_pano_id, (1.349976376677, 103.838462250272): Server disconnected
# find_pano_id, (1.35185377581784, 103.840090911682): Server disconnected
# find_pano_id, (1.35331252531161, 103.840619443577): Server disconnected
# find_pano_id, (1.3513602941792, 103.839712758325): Server disconnected
# find_pano_id, (1.3521211111511, 103.837837840895): Server disconnected
# find_pano_id, (1.35078533774216, 103.837712587851): Server disconnected
# find_pano_id, (1.35453794103526, 103.840043410255): Server disconnected
# find_pano_id, (1.35220132499778, 103.840205552065): Server disconnected
# find_pano_id, (1.34897104352923, 103.83964721185): Server disconnected
# find_pano_id, (1.35421916954944, 103.839392633535): Server disconnected
# find_pano_id, (1.35094010136675, 103.840076758555): Server disconnected
# find_pano_id, (1.35115273213489, 103.837734082539): Server disconnected
# find_pano_id, (1.35126414593845, 103.8399890092): Server disconnected
# find_pano_id, (1.3517644701113, 103.840063136171): Server disconnected
# find_pano_id, (1.35307587309258, 103.838270035548): Server disconnected
# find_pano_id, (1.34875234294063, 103.837787598135): Server disconnected
# find_pano_id, (1.34991497822395, 103.837729482853): Server disconnected
# find_pano_depth, KN7bnX4tNYCpKdRNU1ccAQ: Server disconnected
# find_pano_depth, Z9TvI8pI4XiIEpUn5ugHPA: Server disconnected
# find_pano_depth, vZwbAnREvJJJJgz8MfX3OQ: Server disconnected
# find_pano_depth, fm8_31-SnM6ei1nOq40cuQ: Server disconnected
# find_pano_depth, pCeKVfvA5B6nWiS9BzF-sw: Server disconnected
# find_pano_depth, xp6vvUwKUwJSbtIXHucbSw: Server disconnected
# find_pano_depth, Ljyea7kdLkiKqsbBLfDW6Q: Server disconnected
# find_pano_depth, fvErgGYmbW3Z0iP22moaRg: Server disconnected
# find_pano_depth, fP8t8O7ybYnVZx5_-MhDhg: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_depth, yHFVcrJrCSoPC7e9HBrw0Q: Server disconnected
# save_pano_point_cloud, pRCiy4HOjnKbd6m7gEGg_Q: Server disconnected
# save_pano_point_cloud, o_7IN-WrpVAfr1MbCxfJ5A: Server disconnected
# save_pano_point_cloud, 8UIH7aHtguv8V4qhNJpUVw: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, EbKUAONAbeFD2CKdfwZgCQ: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, NKfAhYakyQo5BHNhETna3Q: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# find_pano_depth, _BZ94-r5d1YLuQKkjV-Kow: Cannot connect to host www.google.com:443 ssl:default [None]
# save_pano_point_cloud, LKCJU_TY1B0AV2x9i9m06A: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, vByVatV1GaxPIM5PL_96Pg: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, I-79EwkBS4LS4cdPXYvCKQ: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, dBWfsyXnW2pFIphfdcXHFQ: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# find_pano_depth, btWaVPhxJTipLE1N932KgQ: Server disconnected
# find_pano_depth, 3xbMLqffNxgE9USFy5iDSQ: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_depth, 5aBMGSWNxHlqdX6ngmliVg: Cannot connect to host www.google.com:443 ssl:default [None]
# save_pano_point_cloud, I0mR_hcARWhhW_SK2d7_6w: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, vz5Be_jC6OoJWWQolfs5FQ: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, Til-RyrquGy-OMcPDDsVgQ: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, Udhj69Uv9iGEKz0XNmIk-g: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, Ct9S1a3opkKGHcWXrK9CfQ: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, wkKjVBTos6eYhKcORvvD9A: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, 3PZBlQZ-EtaqmERTDwZe-g: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, cdt2ZBsqVsORf0e8AzHwnw: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, j1k0Ahfz-2yHKfZDvZQgnA: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, fdUQZt5j0pbmkQ4dzIopiQ: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, FZM5DsRWoxrX8On4gVuYfg: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, yT0QL5RwAVfSInf0LONHlQ: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, tO14Ag10lYj_qdFd0yc6oA: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, 5hc5a2-bJ_o7HAzPoRS7fw: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# find_pano_depth, S6iqxJdW2S-C2fDw4JY46A: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_depth, Y5ztHI_-pI3NLR1dRs9EbA: Cannot connect to host www.google.com:443 ssl:default [None]
# save_pano_point_cloud, 2AU7UyxI16LxRNF1M-0h3A: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, UpBYMQ5YDct5EAroHMpSNw: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# find_pano_depth, Ts9GcSbDOxG6rHaFP35eQA: Cannot connect to host www.google.com:443 ssl:default [None]
# find_pano_depth, X5DAgFpgwNj1Ny21JqxEEg: Cannot connect to host www.google.com:443 ssl:default [None]
# save_pano_point_cloud, jlPv3_Y2IYrw2QtNFwMtRA: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, gtPkZBnZHoV6BEf0eKrAsw: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# find_pano_depth, fAFYR7EP-Sg-6ZMsD06i0g: Server disconnected
# find_pano_depth, KhoaTM9XEMMb9yZe9YIqIw: Server disconnected
# find_pano_depth, ikBnp2xOY2LzsOMPM3C4fw: Server disconnected
# save_pano_point_cloud, LVc49zte9HrOzUbSPYXhRA: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, ug9AkPFqatR6Mdet2wvB2A: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, dz-vTyBm6bG33Z0FmsTGdg: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, Gqtig-lvR45OB_C8nbjQpQ: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, JY6IRnvU9BvuPbHF62_Siw: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, MRIFzZNOWVDbkvqmCf_Jlg: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, yOnYPCQ9fVP16YfXPzZuXg: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, A6TuV3gPX8oC8ZSCxy2F5A: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, 6GPlTJSTmN6gJpZL6II_hA: Server disconnected
# save_pano_point_cloud, Ttdh8yjeX4wf9m17PYd0tA: Server disconnected
# save_pano_point_cloud, S0EdM-2ULukNH-dIi1QJ5Q: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, aVX3IXxn1bKB6ir8d7IKPg: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, abIYQX3btFUGqwU0bB8b_Q: Server disconnected
# save_pano_point_cloud, 6nk0YqejN0aN1_pmMI4lyg: Server disconnected
# save_pano_point_cloud, cBb0beh8zcWjMToEyF27BQ: Server disconnected
# save_pano_point_cloud, Qd4ClbNd4CGI2efpTNuy4Q: Server disconnected
# save_pano_point_cloud, cCqEGuI6U2e3efS6LkLMLQ: Server disconnected
# save_pano_point_cloud, pdqJblOuOKdf_Qkq4jgRXQ: Server disconnected
# save_pano_point_cloud, kAgrXlssLVQFkPbAj9-bDg: Server disconnected
# save_pano_point_cloud, DlPxvwlCQiVwnCCrS43vqQ: Server disconnected
# save_pano_point_cloud, i9YEyOL2VK1Xl2rBlxpQDQ: Server disconnected
# save_pano_point_cloud, mASO5i401ICodYokfq89uA: Server disconnected
# save_pano_point_cloud, YkhB-otBD83FghAGpx5tXA: Server disconnected
# find_pano_depth, HbRW7pMTR6HJderQanNuVg: Server disconnected
# save_pano_point_cloud, nEdImtHsBJAFQOaem_KmUQ: Server disconnected
# save_pano_point_cloud, _ljMJWbtb5oIZSbp3BTlzA: Server disconnected
# save_pano_point_cloud, lJJ9xaH9E8Vv7PGQcvzx0g: Server disconnected
# save_pano_point_cloud, x5P0IuZj53tcH9TUqkOX2A: Server disconnected
# save_pano_point_cloud, YBBA3mKokWX-87hg3NvQEQ: Server disconnected
# save_pano_point_cloud, dZf9rhcNvYrb08-grYAMLQ: Server disconnected
# save_pano_point_cloud, 3PhpUoqo_Gt-SsE6RE0roA: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, q0DVH3NgZIUDkmd5JpptVQ: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, Tjo66WE8M5B9K1MVnGMelw: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, klzdRinI6n36R4XxePW3XQ: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# find_pano_depth, mA2nuboLVXfEZo-QlnorKQ: Cannot connect to host www.google.com:443 ssl:default [None]
# save_pano_point_cloud, R_mOuuxJwmr7huXRi96CIg: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, aSCELNZVkcIH2sCzMFX4YA: Server disconnected
# save_pano_point_cloud, H6_Sz-lXcu5rIQA6NzMOMA: Server disconnected
# save_pano_point_cloud, 7ZUtpcuIyhjfIuITnDWumQ: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, gE162vD9-QIydnLfAgdl_Q: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, CmWBWNa1CvW2Ghhpn0RDzQ: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, fmVZYo1WLSQQdNGxbP6rfQ: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, rWSlVRWZOxoKNyt7-TTz9g: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, wOrnyx8MmF7PdlX4hqi-dw: Server disconnected
# save_pano_point_cloud, Gf6WONwbGSG263QguInO_w: Server disconnected
# save_pano_point_cloud, ecXZrWYgCgXgdvLGv-Tk7Q: Server disconnected
# save_pano_point_cloud, l-Jg7SPdR0m8ny1_3iidfA: Server disconnected
# save_pano_point_cloud, 6BIdd25Xue1gg2qKuZSszA: Server disconnected
# save_pano_point_cloud, 9p2kCRhrq-JdnVph7vzrcA: Server disconnected
# save_pano_point_cloud, 9P21vU9gzifCpwVzfrAwKw: Server disconnected
# save_pano_point_cloud, Bpx40EaEOcVlqxTTaHTqqw: Server disconnected
# save_pano_point_cloud, unR4xtBUryFvuybIQ4H8EA: Server disconnected
# save_pano_point_cloud, E1EA-XHuQZhAlvN2Shc2Kg: Server disconnected
# save_pano_point_cloud, 1L5pV3a1iACEmQ3pjklGjQ: Server disconnected
# save_pano_point_cloud, 3zCHR_H9hX0KRA-c_pmrjA: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, 4cAEMKInHOrd2-bhbjWt1A: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, Nhl-mZrMWSV9_Bi5fdhlIg: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, B6fIBMNNtkROWrRjUlRpvw: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, zCqkrn7EgVKa8N01oMo1hQ: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, seE-3iIvW7VftAhyYt3B2A: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, KOB9iVm8x7lq4a92oqfG8g: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, M10g2tsFNIGpQGsubUSDug: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, L51uM-A9Wf2Ks5EhLAXlug: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, qQxRmHJNC_vMP4JlmxpWwg: Cannot connect to host cbk0.google.com:443 ssl:default [None]
# save_pano_point_cloud, rU6WQaoTI-4xtKu7ArxMqw: Server disconnected
# save_pano_point_cloud, 8RpUQnFoj9yw35qdr3l1yw: Cannot connect to host cbk0.google.com:443 ssl:default [None]
